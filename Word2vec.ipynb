# %% [markdown]
# # Word2vec

# %%
# 부모 폴더의 경로를 추가
import sys; sys.path.insert(0, '..')

from util.data_loader import DataLoader
from util.metric_calculator import MetricCalculator

# %%
# Movielens 데이터 로딩
data_loader = DataLoader(num_users=1000, num_test_items=5, data_path='./data/ml-10M100K/')
movielens = data_loader.load()

# %% [markdown]
# ### Gensim

# %% [markdown]
# Gensim은 최신 통계 기계 학습을 사용하여 비지도 주제 모델링 , 문서 색인화 , 유사성 검색 및 기타 자연어 처리 기능을 위한 오픈 소스 라이브러리 입니다.
# Gensim은 성능을 위해 Python 및 Cython 으로 구현되었습니다.
# Gensim은 데이터 스트리밍 및 증분 온라인 알고리즘을 사용하여 대규모 텍스트 컬렉션을 처리하도록 설계되었으며,
# 이는 메모리 내 처리만을 대상으로 하는 대부분의 다른 기계 학습 소프트웨어 패키지와 차별화됩니다.

# %%
# !pip install --user gensim

# %%
movielens
# Out:
# Dataset(train=        user_id  movie_id  rating   timestamp  \
# 1           139       122     3.0   974302621
# 2           149       122     2.5  1112342322
# 3           182       122     3.0   943458784
# 4           215       122     4.5  1102493547
# 6           281       122     3.0   844437024
# ...         ...       ...     ...         ...
# 132825     1045     57949     0.5  1215617256
# 132826     1045     58291     0.5  1215616991
# 132827     1045     59306     3.0  1215617137
# 132828     1045     60286     3.0  1215617037
# 132829     1047     52952     4.0  1203399887
#
#                                       title                        genre  \
# 1                          Boomerang (1992)            [Comedy, Romance]
# 2                          Boomerang (1992)            [Comedy, Romance]
# 3                          Boomerang (1992)            [Comedy, Romance]
# 4                          Boomerang (1992)            [Comedy, Romance]
# 6                          Boomerang (1992)            [Comedy, Romance]
# ...                                     ...                          ...
# 132825  Welcome Home, Roscoe Jenkins (2008)                     [Comedy]
# 132826             College Road Trip (2008)                     [Comedy]
# 132827                    Prom Night (2008)  [Horror, Mystery, Thriller]
# 132828                Finding Amanda (2008)              [Comedy, Drama]
# 132829               This Is England (2006)                      [Drama]
#
#                                                       tag  rating_order
# 1       [dating, nudity (topless - brief), can't remem...         408.0
# 2       [dating, nudity (topless - brief), can't remem...          84.0
# 3       [dating, nudity (topless - brief), can't remem...        1104.0
# 4       [dating, nudity (topless - brief), can't remem...         320.0
# 6       [dating, nudity (topless - brief), can't remem...          42.0
# ...                                                   ...           ...
# 132825                                                NaN          76.0
# 132826                          [road trip, movie to see]         128.0
# 132827                                           [remake]         102.0
# 132828                                                NaN         120.0
# 132829  [to see, netwatch, less than 300 ratings, less...          47.0
#
# [127830 rows x 8 columns], test=        user_id  movie_id  rating   timestamp                           title  \
# 0             1       122     5.0   838985046                Boomerang (1992)
# 5           217       122     3.0   844429650                Boomerang (1992)
# 33          892       122     4.0   850079961                Boomerang (1992)
# 46           59       185     3.0   838984807                 Net, The (1995)
# 47           62       185     5.0   834874598                 Net, The (1995)
# ...         ...       ...     ...         ...                             ...
# 132657      849      5097     4.0  1013470449              Bright Eyes (1934)
# 132660      951       638     4.0   849628182           Jack and Sarah (1995)
# 132717     1005      1384     5.0   897254984   Substance of Fire, The (1996)
# 132731      934        56     1.0   945901052  Kids of the Round Table (1995)
# 132804     1018     64997     3.0  1230668562        War of the Worlds (2005)
#
#                                  genre  \
# 0                    [Comedy, Romance]
# 5                    [Comedy, Romance]
# 33                   [Comedy, Romance]
# 46           [Action, Crime, Thriller]
# 47           [Action, Crime, Thriller]
# ...                                ...
# 132657                 [Comedy, Drama]
# 132660                       [Romance]
# 132717                         [Drama]
# 132731  [Adventure, Children, Fantasy]
# 132804                        [Action]
#
#                                                       tag  rating_order
# 0       [dating, nudity (topless - brief), can't remem...           1.0
# 5       [dating, nudity (topless - brief), can't remem...           5.0
# 33      [dating, nudity (topless - brief), can't remem...           5.0
# 46      [computers, computers, internet, irwin winkler...           1.0
# 47      [computers, computers, internet, irwin winkler...           5.0
# ...                                                   ...           ...
# 132657                                                NaN           2.0
# 132660              [babies, ian mckellen, baby, british]           5.0
# 132717                                                NaN           1.0
# 132731                                                NaN           5.0
# 132804                                                NaN           1.0
#
# [5000 rows x 8 columns], test_user2items={1: [122, 362, 466, 520, 616], 3: [3408, 5527], 4: [266, 317], 5: [926, 969, 1172, 1300], 6: [1396, 1527, 1580, 2628], 7: [5505, 1748, 2791, 6273], 8: [3264], 9: [50, 4226, 3429, 7361, 44761], 10: [2194, 2917], 11: [858, 2011, 2407, 2091], 12: [3175], 13: [1089, 2959, 1374], 14: [2125], 16: [1206], 17: [2762, 3147, 1249], 18: [6323, 924, 5785, 6707], 19: [329], 22: [539, 482], 23: [367, 306, 223, 261, 319], 24: [1393, 1047, 64], 26: [733, 780, 587], 27: [836], 28: [1220, 2000, 2371, 2375], 29: [3885], 30: [1064, 1302, 1380], 35: [1921, 2594, 3160, 3556], 37: [541, 778, 1080], 38: [48394, 54286], 40: [457, 36, 3173, 1147], 41: [1772, 2657], 42: [1035, 1079, 1125, 1022], 43: [1409, 1704, 1721, 1680], 44: [1235, 1285, 3039, 1394, 3072], 45: [1610, 866, 695], 46: [1073, 1196, 7361], 47: [1080, 1682, 2012, 2174, 2710], 48: [4369, 55282, 59103], 50: [151, 509], 51: [2202, 4546, 6993], 52: [2433], 53: [3176, 2987, 3114, 3798], 54: [277], 55: [2140, 613, 1884, 6242], 56: [1391, 920, 1079], 57: [1102, 1525, 1578], 58: [410, 2725, 2690, 2721], 59: [161, 10], 60: [1198, 1086, 1321, 1012], 61: [1358, 1393, 3147, 105, 1250], 62: [185, 110, 457], 63: [2396, 2702, 2677], 64: [25], 66: [50, 4226, 2329, 5782], 67: [249, 515, 353, 610], 68: [440, 457, 1213, 154], 69: [1277, 1411, 2357], 71: [480, 110, 288], 72: [377, 586, 648, 367, 597], 73: [1517, 678, 319], 74: [1597, 277, 647], 75: [2571, 2959], 76: [293, 442], 77: [110, 150, 500, 265], 78: [6993, 4119, 8400, 50872], 79: [260, 1089], 80: [144], 81: [2232, 2020], 82: [7153, 531, 46976, 6350], 83: [1262], 84: [1366], 85: [232], 86: [349, 2115, 1372], 87: [3176, 2672, 2987, 3114, 3793], 88: [1027, 1974, 3254, 2605], 89: [356, 308, 144, 177], 90: [799, 837], 91: [151, 593, 1225, 908, 1150], 93: [3479, 42728, 46335, 47382, 51834], 94: [354], 95: [364, 47, 457], 96: [292, 1805, 1003, 2182], 97: [5010, 4816, 5400, 5418], 98: [1357, 866, 1053], 99: [1258, 4973, 1147], 100: [2871], 101: [442, 555], 102: [377, 500, 50], 103: [1228], 104: [1270, 1200, 1291, 750, 1301], 105: [480, 1247, 3512], 106: [934, 2694, 5060], 107: [1276, 1136], 108: [7371, 1354, 7044], 110: [34, 2028], 111: [50], 112: [1639], 113: [2763, 86], 114: [1073, 2657], 115: [778, 1704, 1961], 116: [802, 765, 140, 830], 117: [1220, 3526, 2580], 118: [780, 272], 119: [1120], 120: [88, 333], 121: [926, 2028, 1212, 1272], 122: [2329, 69, 4007], 123: [356, 539, 110, 1183, 4014], 124: [45720], 125: [8361, 4263, 346], 126: [41571], 127: [6958, 45726], 128: [232, 508, 207, 314, 273], 129: [1288], 130: [1304, 1175, 1299, 6385], 131: [509, 104, 247], 134: [74, 628, 1084], 135: [362, 969, 1247, 596], 136: [2120], 137: [2987], 138: [3996, 741, 3052, 3000], 139: [3638, 2034], 140: [356, 4995, 1955, 33166], 141: [539, 587, 515], 142: [50, 296], 143: [1207], 145: [515], 148: [303, 368, 2401], 149: [8493], 150: [508, 357], 151: [588, 595, 1947, 2087, 1022], 152: [377, 1422, 40629], 153: [2815], 154: [3578, 2683, 337], 155: [1387, 2987, 3114, 1784, 2706], 156: [800], 157: [886, 1407, 742, 1399], 158: [198, 350, 444], 161: [5630], 162: [3623, 7143, 59784, 60069], 163: [16, 353], 164: [733, 6], 165: [1276, 1959, 2763], 166: [377, 1127], 167: [1073, 637, 784, 65], 168: [1441, 441], 169: [3863, 2959, 2712], 170: [180, 4251, 6807, 8622], 171: [4306, 454, 2054, 8622], 172: [377, 500, 587], 173: [70, 1373, 423], 174: [293, 2541], 175: [5300, 7700, 50068, 1757, 51540], 176: [356, 480, 110], 177: [1356, 673, 663], 178: [1, 1810], 179: [235, 2696, 1927, 1465, 4809], 180: [527, 593, 2571, 50, 2324], 182: [8949, 8645, 8943], 183: [903, 1207, 908, 2621], 184: [47, 1396, 1466, 2542], 185: [2571, 357, 3004, 1593, 3097], 186: [1129, 4006], 187: [3408, 4061], 188: [780], 189: [1219, 1333, 22], 190: [27611], 191: [858, 1148, 318, 745], 192: [942, 6380, 7564, 33564], 194: [85, 842, 613, 1105], 195: [1210, 5388, 5377], 197: [1260, 1799, 6852], 198: [471, 5772], 199: [364, 500, 2], 200: [1359], 201: [1678], 202: [539, 1961, 2997, 17] ...
# 0             1                    Toy Story (1995)
# 1             2                      Jumanji (1995)
# 2             3             Grumpier Old Men (1995)
# 3             4            Waiting to Exhale (1995)
# 4             5  Father of the Bride Part II (1995)
# ...         ...                                 ...
# 10676     65088              Bedtime Stories (2008)
# 10677     65091          Manhattan Melodrama (1934)
# 10678     65126                        Choke (2008)
# 10679     65130           Revolutionary Road (2008)
# 10680     65133      Blackadder Back & Forth (1999)
#
#                                                    genre  \
# 0      [Adventure, Animation, Children, Comedy, Fantasy]
# 1                         [Adventure, Children, Fantasy]
# 2                                      [Comedy, Romance]
# 3                               [Comedy, Drama, Romance]
# 4                                               [Comedy]
# ...                                                  ...
# 10676                      [Adventure, Children, Comedy]
# 10677                            [Crime, Drama, Romance]
# 10678                                    [Comedy, Drama]
# 10679                                   [Drama, Romance]
# 10680                                           [Comedy]
#
#                                                      tag
# 0      [pixar, pixar, pixar, animation, pixar, animat...
# 1      [for children, game, animals, joe johnston, ro...
# 2      [funniest movies, comedinha de velhinhos engra...
# 3                                           [girl movie]
# 4      [steve martin, pregnancy, remake, steve martin...
# ...                                                  ...
# 10676                                                NaN
# 10677                                                NaN
# 10678                   [chuck palahniuk, based on book]
# 10679                                        [toplist08]
# 10680                                                NaN
#
# [10681 rows x 4 columns])

# %%
import gensim
import logging

movie_content = movielens.item_content.copy()

# %%
movie_content
# Out:
#        movie_id                               title  \
# 0             1                    Toy Story (1995)
# 1             2                      Jumanji (1995)
# 2             3             Grumpier Old Men (1995)
# 3             4            Waiting to Exhale (1995)
# 4             5  Father of the Bride Part II (1995)
# ...         ...                                 ...
# 10676     65088              Bedtime Stories (2008)
# 10677     65091          Manhattan Melodrama (1934)
# 10678     65126                        Choke (2008)
# 10679     65130           Revolutionary Road (2008)
# 10680     65133      Blackadder Back & Forth (1999)
#
#                                                    genre  \
# 0      [Adventure, Animation, Children, Comedy, Fantasy]
# 1                         [Adventure, Children, Fantasy]
# 2                                      [Comedy, Romance]
# 3                               [Comedy, Drama, Romance]
# 4                                               [Comedy]
# ...                                                  ...
# 10676                      [Adventure, Children, Comedy]
# 10677                            [Crime, Drama, Romance]
# 10678                                    [Comedy, Drama]
# 10679                                   [Drama, Romance]
# 10680                                           [Comedy]
#
#                                                      tag
# 0      [pixar, pixar, pixar, animation, pixar, animat...
# 1      [for children, game, animals, joe johnston, ro...
# 2      [funniest movies, comedinha de velhinhos engra...
# 3                                           [girl movie]
# 4      [steve martin, pregnancy, remake, steve martin...
# ...                                                  ...
# 10676                                                NaN
# 10677                                                NaN
# 10678                   [chuck palahniuk, based on book]
# 10679                                        [toplist08]
# 10680                                                NaN
#
# [10681 rows x 4 columns]

# %%
 movie_content['tag'].fillna("").apply(list)
# Out:
# 0        [pixar, pixar, pixar, animation, pixar, animat...
# 1        [for children, game, animals, joe johnston, ro...
# 2        [funniest movies, comedinha de velhinhos engra...
# 3                                             [girl movie]
# 4        [steve martin, pregnancy, remake, steve martin...
#                                ...
# 10676                                                   []
# 10677                                                   []
# 10678                     [chuck palahniuk, based on book]
# 10679                                          [toplist08]
# 10680                                                   []
# Name: tag, Length: 10681, dtype: object

# %%
 movie_content['genre'].apply(list)
# Out:
# 0        [Adventure, Animation, Children, Comedy, Fantasy]
# 1                           [Adventure, Children, Fantasy]
# 2                                        [Comedy, Romance]
# 3                                 [Comedy, Drama, Romance]
# 4                                                 [Comedy]
#                                ...
# 10676                        [Adventure, Children, Comedy]
# 10677                              [Crime, Drama, Romance]
# 10678                                      [Comedy, Drama]
# 10679                                     [Drama, Romance]
# 10680                                             [Comedy]
# Name: genre, Length: 10681, dtype: object

# %%
# tag가 부여되어 있지 않은 영화가 있지만. genre는 모든 영화에 부여되어 있다
# tag와 genre를 결합한 것을 영화의 콘텐츠 정보로 해서 비슷한 영화를 찾아서 추천한다
# tag가 없는 영화에서는 NaN으로 되어 있으므로, 빈 리스트로 초기화한다
movie_content['tag_genre'] = movie_content['tag'].fillna("").apply(list) + movie_content['genre'].apply(list)
movie_content['tag_genre']
# Out:
# 0        [pixar, pixar, pixar, animation, pixar, animat...
# 1        [for children, game, animals, joe johnston, ro...
# 2        [funniest movies, comedinha de velhinhos engra...
# 3                     [girl movie, Comedy, Drama, Romance]
# 4        [steve martin, pregnancy, remake, steve martin...
#                                ...
# 10676                        [Adventure, Children, Comedy]
# 10677                              [Crime, Drama, Romance]
# 10678      [chuck palahniuk, based on book, Comedy, Drama]
# 10679                          [toplist08, Drama, Romance]
# 10680                                             [Comedy]
# Name: tag_genre, Length: 10681, dtype: object

# %%
movie_content['tag_genre'][0]
# Out:
# ['pixar',
#  'pixar',
#  'pixar',
#  'animation',
#  'pixar',
#  'animated',
#  'fun',
#  'toy',
#  'toys',
#  'pixar',
#  'rated-g',
#  'pixar',
#  'pixar',
#  'national film registry',
#  'time travel',
#  'pixar',
#  'pixar',
#  'funny',
#  'imdb top 250',
#  'animation',
#  'very good',
#  'ya boy',
#  'pixar',
#  'time travel',
#  'animation',
#  "erlend's dvds",
#  'cgi',
#  'disney',
#  'family',
#  'pixar',
#  'toys',
#  'bright',
#  'daring rescues',
#  'fanciful',
#  'heroic mission',
#  'humorous',
#  'light',
#  'rousing',
#  'toys come to life',
#  'unlikely friendships',
#  'warm',
#  'witty',
#  'pixar',
#  'the boys',
#  'almost favorite',
#  'é˜®ä¸€é¸£',
#  'animation',
#  'children',
#  'disney',
#  'pixar',
#  'clever',
#  'want to see again',
#  'cartoon',
#  'disney',
#  '3d',
#  'computer animation',
#  'disney animated feature',
#  'pixar animation',
#  'want',
#  'buddy movie',
#  'animation',
#  'pixar',
#  'tim allen',
#  'tom hanks',
#  'animation',
#  'disney',
#  'pixar',
#  'toys',
#  'computer animation',
#  'cartoon',
#  'pixar',
#  'animation',
#  'computer animation',
#  'pixar',
#  'toys',
#  "tumey's to see again",
#  "tumey's vhs",
#  'classic',
#  'disney',
#  'engaging',
#  'avi',
#  'buy',
#  'action figure',
#  'action figures',
#  'buzz lightyear',
#  'cg animation',
#  'toy',
#  'toys',
#  'woody',
#  'disney',
#  'pixar',
#  'tim allen',
#  'tom hanks',
#  'animation',
#  'pixar',
#  'animation',
#  'kids movie',
#  'pixar',
#  'tim allen',
#  'time travel',
#  'animation',
#  'cgi',
#  'adventure',
#  'animation',
#  'children',
#  'comedy',
#  'animation',
#  'pixar',
#  'lots of heart',
#  'animation',
#  'pixar',
#  'adventure',
#  'animation',
#  'comedy',
#  'family',
#  'fantasy',
#  'john lasseter',
#  'usa',
#  'animation',
#  'disney',
#  'pixar',
#  'classic',
#  'pixar',
#  'first cgi film',
#  'animation',
#  'disney',
#  'disney',
#  'animation',
#  'pixar',
#  'pixar',
#  'pixar',
#  'animation',
#  'disney',
#  'villian hurts toys',
#  'pixar',
#  'computer animation',
#  'pixar',
#  'animated',
#  'cgi',
#  'comedy',
#  'Adventure',
#  'Animation',
#  'Children',
#  'Comedy',
#  'Fantasy']

# %%
movie_content['tag_genre'] = movie_content['tag_genre'].apply(lambda x:set(map(str, x)))

# %%
movie_content['tag_genre']
# Out:
# 0        {bright, toys come to life, very good, rated-g...
# 1        {kirsten dunst, Adventure, children, time, her...
# 2        {moldy, comedinha de velhinhos engraã§ada, Rom...
# 3                     {Romance, girl movie, Comedy, Drama}
# 4        {remake, it thought it was funny but it wasn't...
#                                ...
# 10676                        {Adventure, Comedy, Children}
# 10677                              {Romance, Drama, Crime}
# 10678      {based on book, Comedy, chuck palahniuk, Drama}
# 10679                          {Romance, toplist08, Drama}
# 10680                                             {Comedy}
# Name: tag_genre, Length: 10681, dtype: object

# %%
# 태그와 장르 데이터를 사용해서, word2vec를 학습한다
tag_genre_data = movie_content.tag_genre.tolist()

# %%
tag_genre_data
# Out:
# [{'3d',
#   'Adventure',
#   'Animation',
#   'Children',
#   'Comedy',
#   'Fantasy',
#   'action figure',
#   'action figures',
#   'adventure',
#   'almost favorite',
#   'animated',
#   'animation',
#   'avi',
#   'bright',
#   'buddy movie',
#   'buy',
#   'buzz lightyear',
#   'cartoon',
#   'cg animation',
#   'cgi',
#   'children',
#   'classic',
#   'clever',
#   'comedy',
#   'computer animation',
#   'daring rescues',
#   'disney',
#   'disney animated feature',
#   'engaging',
#   "erlend's dvds",
#   'family',
#   'fanciful',
#   'fantasy',
#   'first cgi film',
#   'fun',
#   'funny',
#   'heroic mission',
#   'humorous',
#   'imdb top 250',
#   'john lasseter',
#   'kids movie',
#   'light',
#   'lots of heart',
#   'national film registry',
#   'pixar',
#   'pixar animation',
#   'rated-g',
#   'rousing',
#   'the boys',
#   'tim allen',
#   'time travel',
#   'tom hanks',
#   'toy',
#   'toys',
#   'toys come to life',
#   "tumey's to see again",
#   "tumey's vhs",
#   'unlikely friendships',
#   'usa',
#   'very good',
#   'villian hurts toys',
#   'want',
#   'want to see again',
#   'warm',
#   'witty',
#   'woody',
#   'ya boy',
#   'é˜®ä¸€é¸£'},
#  {'Adventure',
#   'Children',
#   'Fantasy',
#   'adapted from:book',
#   'animals',
#   'board game',
#   'childhood recaptured',
#   'children',
#   'fantasy',
#   'filmed in bc',
#   'for children',
#   'game',
#   'herds of cgi animals',
#   'joe johnston',
#   'jungle',
#   'kid flick',
#   'kirsten dunst',
#   'lebbat',
#   'monkey',
#   'robin williams',
#   'saturn award (best special effects)',
#   'saturn award (best supporting actress)',
#   'scary',
#   'see also:zathura',
#   'time',
#   'time travel'},
#  {'Comedy',
#   'Romance',
#   'comedinha de velhinhos engraã§ada',
#   'comedinha de velhinhos engraãƒâ§ada',
#   'funniest movies',
#   'grun running',
#   'jack lemmon',
#   'moldy',
#   'old',
#   'old people that is actually funny',
#   'sequel fever',
#   'walter matthau'},
#  {'Comedy', 'Drama', 'Romance', 'girl movie'},
#  {'Comedy',
#   'childhood classics',
#   'family',
#   'fantasy',
#   "it thought it was funny but it wasn't",
#   'pregnancy',
#   'remake',
#   'sequel',
#   'sequel fever',
#   'steve martin',
#   'watched under duress',
#   'wedding',
#   'worst movies ever'},
#  {'1',
#   'Action',
#   'Crime',
#   'Thriller',
#   'al and robert',
#   'al pacino',
#   'atmospheric',
#   'bibliothek',
#   'bleak',
#   "can't remember",
#   'clearplay',
#   'ending lame',
#   'guns',
#   'imdb top 250',
#   'in the nucleus',
#   'long',
#   'need to own',
#   'overrated',
#   'owned',
#   'r',
#   'recommendz top pick',
#   'robert de niro',
#   'setting:la',
#   'slick',
#   'somber',
#   'tense',
#   'too long',
#   'top 10 ever',
#   "tumey's dvds",
#   'visceral',
#   'vontatott',
#   'want',
#   'who cares dvds',
#   'witty'},
#  {'Comedy',
#   'Romance',
#   'based on a play',
#   'chick flick',
#   'greg kinnear',
#   'harrison ford',
#   'relationships',
#   'remadeas:sabrina(1995)',
#   'remake',
#   'remakeof:sabrina(1954)',
#   'romance',
#   'sexuality',
#   'upstairs-downstairs'},
#  {'Adventure', 'Children', 'adapted from:book', 'author:mark twain'},
#  {'Action', "can't remember", 'jean-claude van damme'},
#  {'007',
#   '007 (series)',
#   'Action',
#   'Adventure',
#   'Thriller',
#   'action',
#   'adventure',
#   'assassin',
#   'best of the brosnon bonds',
#   'bond',
#   'boys with toys',
#   'espionage',
#   'franchise',
#   'gadgets',
#   'good dialogue',
#   'i wanted the bad guy to win.  sean bean out-bonds bond.',
#   "it's a good movie but the end of 007 is always the same",
#   'its an ok movie if you like  james bound.',
#   'james bond',
#   'killer as protagonist',
#   'murder',
#   'owned',
#   'pierce brosnan',
#   'sean bean dies',
#   'secret service',
#   'seen more than once',
#   'sequel',
#   'spies',
#   'tank chase scene',
#   "tumey's dvds",
#   'violence'},
#  {'23.03.06',
#   'Comedy',
#   'Drama',
#   'Romance',
#   'aaron sorkin',
#   'amazing kung fu',
#   'bibliothek',
#   'cute',
#   'decent flick',
#   'drama',
#   'dvd collection',
#   'girlie movie',
#   'politics',
#   'president',
#   'romance',
#   'seen',
#   'seen more than once',
#   'us president',
#   'white house'},
#  {'Comedy', 'Horror', 'gothic', 'mel brooks', 'spoof', 'vampire'},
#  {'Animation', 'Children', 'dogsled', 'ei muista', 'sort of boring'},
#  {'5',
#   'Drama',
#   'anthony hopkins',
#   'based on a true story',
#   'biographical',
#   'biography',
#   'biopic',
#   'character based on real person:richard nixon',
#   'cinematographer:robert richardson',
#   'drama',
#   'historical opinion',
#   'oliver stone',
#   'own',
#   'political drama',
#   'politics',
#   'president',
#   "tumey's vhs",
#   'us president',
#   'wooohoo'},
#  {'Action', 'Adventure', 'Romance', 'pirate', 'pirates'},
#  {'20060407',
#   'Crime',
#   'Drama',
#   'based on a book',
#   'bibliothek',
#   'cannibalism',
#   'cinematographer:robert richardson',
#   'complex',
#   'cult film',
#   'de niro in pink',
#   'deniro',
#   'divx1',
#   "eric's dvds",
#   'gangster',
#   'goodfellas ii',
#   'imdb top 250',
#   'las vegas',
#   'mafia',
#   'martin scorsese',
#   'masterpiece',
#   'mob',
#   'narrated',
#   'need to own',
#   'non-fiction',
#   'nudity (rear)',
#   'nudity (topless - brief)',
#   'on dvr',
#   'pesci',
#   'robert de niro',
#   'robert deniro',
#   'scorcese',
#   "tumey's dvds",
#   'vegas',
#   'violent',
#   'watch'},
#  {'Comedy',
#   'Drama',
#   'Romance',
#   'adapted from:book',
#   'alan rickman',
#   'ang lee',
#   'author:jane austen',
#   'based on a book',
#   'bibliothek',
#   'boring',
#   'british',
#   'chick flick',
#   'classic',
#   'emma thompson',
#   'english',
#   'great adaptations',
#   'great screenplays',
#   'historical',
#   'hulu',
#   'jane austen',
#   'kate winslet',
#   'literature',
#   'nothing happens',
#   'period',
#   'regency england',
#   'romance',
#   'shakespeare',
#   "sven's to see list"},
#  {'4',
#   'Comedy',
#   'Drama',
#   'Thriller',
#   'alexandre rockwell',
#   'allison anders',
#   'comedy',
#   'corpse in the bed',
#   'drama',
#   'multiple storylines',
#   'nudity (topless)',
#   'own',
#   'quentin tarantino',
#   'robert rodriguez',
#   'rodriguez',
#   'tarantino',
#   'thriller',
#   "tumey's vhs"},
#  {'Comedy',
#   'africa',
#   'comedy',
#   'crazy',
#   'hehehe',
#   'jim carrey',
#   'not my kind of comedy',
#   'one of the worst movies of all time',
#   'rhino action :d',
#   'steve oedekerk'},
#  {'Action',
#   'Comedy',
#   'Crime',
#   'Drama',
#   'Thriller',
#   'afternoon section',
#   'intense',
#   'lame',
#   'lopez',
#   'money',
#   'nudity (topless - brief)',
#   'worthwhile'},
#  {'Action',
#   'Comedy',
#   'Drama',
#   'crime',
#   'foqam',
#   'funny!',
#   'gene hackman',
#   'getting old but still excellent',
#   'hilarious!',
#   'hollywood',
#   'john travolta',
#   'mafia',
#   'mob',
#   'owned',
#   'satire',
#   'satire:hollywood insiders',
#   'travolta',
#   'watch'},
#  {'Crime', 'Drama', 'Horror', 'Mystery', 'Thriller', 'serial killer'},
#  {'2.5', 'Action', 'Crime', 'Thriller', 'afternoon section', 'divx1', 'kill'},
#  {'Drama',
#   'Sci-Fi',
#   'albino',
#   "can't remember",
#   'earnest',
#   'elegiac',
#   'inane',
#   'misunderstood character teaches us all a cheesy lesson',
#   'owned',
#   'poignant',
#   'post apocalyptic',
#   'pretentious',
#   'reflective',
#   'special powers',
#   'tearjerking'},
#  {'Drama',
#   'Romance',
#   'addiction',
#   'alcoholism',
#   'atmospheric',
#   'bibliothek',
#   'dark',
#   'depressing',
#   'elegiac',
#   'elisabeth - emotion!',
#   'intimate',
#   'library',
#   'loneliness',
#   'love is not enough',
#   'melancholy',
#   'nicolas cage',
#   'nudity (topless)',
#   'oscar (best actor)',
#   'overrated',
#   'owned',
#   'poignant',
#   'prostitutes',
#   'star-crossed lovers',
#   'suicide',
#   'understated'},
#  {'Drama',
#   'adapted from:play',
#   'based on a play',
#   'ei muista',
#   'great',
#   'nudity (topless)',
#   'playwright:shakespeare',
#   'shakespeare',
#   'shakespearean',
#   'wow'},
#  {'Drama'},
#  {'?adapted from:book',
#   '?author:jane austen',
#   'Drama',
#   'Romance',
#   'adaptation',
#   'based on a book',
#   'fiona shaw',
#   'in netflix queue',
#   'jane austen',
#   'library vhs',
#   'oppl'},
#  {'2.5',
#   'Adventure',
#   'Drama',
#   'Fantasy',
#   'Mystery',
#   'Sci-Fi',
#   'abused children',
#   'atmospheric',
#   'beautiful',
#   'bleak',
#   'children',
#   'clowny clones',
#   'dark fairytale',
#   'dark fantasy',
#   'dreamlike',
#   'dystopia',
#   "erlend's dvds",
#   'fanciful',
#   'hallucinatory',
#   'jeunet',
#   'kidnapping',
#   'legenda pt-br',
#   'mechanized',
#   'need to own',
#   'netflix instant watching',
#   'on computer',
#   'santa claus',
#   'sci-fi',
#   'skinut',
#   'steampunk',
#   'stylized',
#   'surreal',
#   'visually appealing',
#   'whimsical'},
#  {'Crime', 'Drama'},
#  {'Drama',
#   'afternoon section',
#   'bibliothek',
#   'crime',
#   'dangerous minds',
#   'drama',
#   "erlend's dvds",
#   'high school',
#   'island',
#   'own',
#   'seen at the cinema',
#   'teacher',
#   'teacher as protagonist'},
#  {'3',
#   'Sci-Fi',
#   'Thriller',
#   'adapted from/inspired by:short film',
#   'adventure',
#   'after you watch it you spend hours thinkig about it',
#   'altering history',
#   'asylum',
#   'based on short film',
#   'biological warfare',
#   'biology',
#   'brad pitt',
#   'brilliant',
#   'bruce willis',
#   'classic',
#   'clearplay',
#   'complicated',
#   'depressing',
#   'divx1',
#   'drama',
#   'dvd',
#   'dvd-video',
#   'dystopia',
#   'dystopian',
#   'dystopian future',
#   'dystopic future',
#   'end of the world',
#   'excellent',
#   'future',
#   'futuristmovies.com',
#   'genetics',
#   'genius',
#   'get',
#   'gfei own it',
#   'gilliam',
#   'good as hell',
#   'great actors',
#   'imdb top 250',
#   'interesting',
#   'joseph melito',
#   'madeleine stowe',
#   'memory remains',
#   'mindfuck',
#   'mindfuck movie',
#   'monty-python-related',
#   "my favorite reviewers disliked this film: that's when i started to trust them less",
#   'nature of insanity',
#   'not seen',
#   'overrated',
#   'owned',
#   'plot point:bio-medical danger',
#   'post apocalyptic',
#   'post-apocalyptic',
#   'psychology',
#   'r',
#   'remake',
#   'remake of a french film',
#   'saturn award (best costumes)',
#   'saturn award (best science fiction film)',
#   'saturn award (best supporting actor)',
#   'sci-fi',
#   'sci-fi. dark',
#   'seen at the cinema',
#   'sf',
#   'special',
#   'strong director',
#   'terry gilliam',
#   'thriller',
#   'time paradox',
#   'time travel',
#   "tumey's dvds",
#   'twist ending',
#   'vhs',
#   'violence',
#   'weird good film'},
#  {'Adventure', 'IMAX', 'Romance'},
#  {'Children',
#   'Comedy',
#   'Drama',
#   'Fantasy',
#   'adventure',
#   'afi 100 (cheers)',
#   'animal',
#   'animal movie',
#   'animal:pig',
#   'animals',
#   'barnyard animals',
#   'biography',
#   'boring',
#   'chris noonan',
#   'clv',
#   'dvd collection',
#   'farm tale',
#   'favorite',
#   'hugo weaving',
#   'infantil',
#   'own',
#   'pig',
#   'pigs',
#   'talking animals',
#   'villain nonexistent or not needed for good story',
#   'way overrated'},
#  {'Drama',
#   'Romance',
#   'artist',
#   'artists',
#   'biopics',
#   'emma thompson',
#   'on dvr',
#   'strong woman'},
#  {'2',
#   'Crime',
#   'Drama',
#   'abe',
#   'ari',
#   'based on a book',
#   'book',
#   'buy',
#   "can't remember",
#   "couldn't finish",
#   'crime',
#   'deaf',
#   'death',
#   'death penalty',
#   'death row',
#   'drama',
#   'emotion!',
#   'ethics',
#   'institutions',
#   'knoll',
#   'moral dilemma',
#   'murder',
#   'nun',
#   'oscar (best actress)',
#   'pena de muerte',
#   'pompadour',
#   'prison',
#   'rated-r',
#   'sean penn',
#   'strong',
#   'tim robbins',
#   'true story',
#   'uk',
#   'usa',
#   'watch'},
#  {'Documentary', 'IMAX'},
#  {'Comedy', 'twins', 'twins/inter-related lives'},
#  {'Comedy',
#   'Romance',
#   'adaptation',
#   'adapted from:book',
#   'alicia silverstone',
#   'author:jane austen',
#   'best comedy',
#   'chick flick',
#   'classic',
#   'comedy',
#   'dumb teen',
#   'emma',
#   'fashion',
#   'girlie movie',
#   'high school',
#   'jane austen',
#   'like for sure',
#   'omigawd!',
#   'romance',
#   'saw it ten times',
#   'seen more than once',
#   'teen',
#   'updated classics',
#   'very funny!',
#   'want to own'},
#  {'Drama', 'disk', 'in netflix queue', 'south africa'},
#  {'Drama',
#   'War',
#   'adapted from:play',
#   'based on a play',
#   'ian mckellen',
#   'playwright:shakespeare',
#   'robert downey jr',
#   'shakespeare',
#   'updated classics'},
#  {'Action', 'Crime', 'Drama', 'bank robbery', "eric's dvds"},
#  {'17th century', 'Drama', 'england', 'nudity (topless)'},
#  {'Action',
#   'Adventure',
#   'Fantasy',
#   'adapted from:game',
#   'christopher lambert',
#   'fatality',
#   'martial arts',
#   'movie to see',
#   'seen at the cinema',
#   'video game adaptation'},
#  {'Comedy',
#   'Drama',
#   'Thriller',
#   'best performance:  nicole kidman as suzanne stone maretto',
#   'bibliothek',
#   'clearplay',
#   'dark comedy',
#   "erlend's dvds",
#   'joaquin phoenix',
#   'journalism',
#   'library',
#   'r',
#   'wayne knight'},
#  {'Drama',
#   'Romance',
#   'a chick flick',
#   'bibliothek',
#   'nudity (topless - brief)',
#   'wedding',
#   'winona ryder at her worst'},
#  {'3.5',
#   'Crime',
#   'Horror',
#   'Mystery',
#   'Thriller',
#   'amazing!.',
#   'ashley judd',
#   'aã§ã£o',
#   'bfi modern classic',
#   'biblical',
#   'books',
#   'brad pitt',
#   'bradpitt',
#   'clearplay',
#   'creepy',
#   'crime',
#   'dante',
#   'david fincher',
#   'detective',
#   'disturbing',
#   'divx',
#   'drama',
#   'envy',
#   'evil',
#   'genius horror',
#   'gloomy',
#   'gluttony',
#   'gory',
#   'graphic violence',
#   'greed',
#   'grim',
#   'gruesome',
#   'husband-wife relationship',
#   'imdb top 250',
#   'in netflix queue',
#   'investigation',
#   'kevin spacey',
#   'library vhs',
#   'lust',
#   'menacing',
#   'morgan freeman',
#   'murder',
#   'murder investigations',
#   'mystery',
#   'numbers',
#   'ominous',
#   'owned',
#   'police',
#   'policial',
#   'powerful ending',
#   'pride',
#   'psychological drama',
#   'psychology',
#   'r',
#   'religion',
#   'saturn award (best makeup)',
#   'saturn award (best writing)',
#   'scary',
#   'scary stuff',
#   'scope',
#   'seen at the cinema',
#   'seen more than once',
#   'serial killer',
#   'serial killers',
#   'setting:library',
#   'seven',
#   'seven deadly sins',
#   'severed head in a box',
#   'sin',
#   'sins',
#   'sloth',
#   'spacey: excellent....pitt: brilliant....freeman: wow. a wonderful movie. must must watch',
#   'spannend',
#   'strange',
#   'suitcase of light',
#   'super interesting',
#   'suspenseful',
#   'the best',
#   'theater',
#   'thriller',
#   'top 10 ever',
#   "tumey's dvds",
#   "tumey's to see again",
#   'twists & turns',
#   'usa',
#   'very good',
#   'very good thriller - brad pitt',
#   'vhs',
#   'violent',
#   'want',
#   'want it',
#   'watched 1995',
#   'week',
#   'worst ever',
#   'wrath'},
#  {'1600s',
#   '70mm',
#   'Animation',
#   'Children',
#   'Musical',
#   'Romance',
#   'cartoon',
#   'david ogden stiers',
#   'disney',
#   'disney animated feature',
#   'eric goldberg',
#   'get',
#   'interracial romance',
#   'irene bedard',
#   'john kassir',
#   'judy kuhn',
#   'katottava',
#   'mel gibson',
#   'mike gabriel',
#   'oscar (best music - original score)',
#   'oscar (best music - original song)',
#   'russell means',
#   'ø§ø\xadø³ø§ø³ø§øªùš'},
#  {'Drama',
#   'Romance',
#   'circus',
#   'gay',
#   'lesbian',
#   'nudity (topless - notable)',
#   'own',
#   'religion'},
#  {'3',
#   'Crime',
#   'Mystery',
#   'Thriller',
#   'awesome',
#   'benicio del toro',
#   "best of the 90's",
#   'caper',
#   'caper movie',
#   'clearplay',
#   'complicated',
#   'complot',
#   'conspiracy',
#   'crime',
#   'dark',
#   'dvd',
#   'ensemble cast',
#   "eric's dvds",
#   "erlend's dvds",
#   'fell asleep',
#   'filim noir',
#   'flash back',
#   'flashbacks',
#   'funny',
#   'gabriel byrne',
#   'great ending',
#   'heist',
#   'imdb top 250',
#   'keser soze',
#   'kevin spacey',
#   'kevin spacey is soze',
#   'keyser sose',
#   'keyser soze',
#   'library',
#   'mentiras',
#   'mindfuck',
#   'must be seen more than once',
#   'must see',
#   'must see more than once',
#   'my movies',
#   'organized crime',
#   'oscar (best supporting actor)',
#   'oscar winner',
#   'oscar:supporting actor',
#   'overrated',
#   'own',
#   'owned',
#   'puzzle-like',
#   'r',
#   'robo',
#   'seen at the cinema',
#   'sensational',
#   'spaceyal',
#   'suspense',
#   'tricky',
#   "tumey's dvds",
#   'twist',
#   'twist ending',
#   'unreliable narrators',
#   'very good',
#   'want',
#   'want to see again',
#   'watch-again',
#   'whodunnit'},
#  {'Action', 'Drama', 'Thriller'},
#  {'Comedy',
#   'Drama',
#   'Romance',
#   'adoption',
#   "erlend's dvds",
#   'oscar (best supporting actress)',
#   'prostitution',
#   'seen at the cinema',
#   'watched 1995',
#   'woody allen'},
#  {'Adventure', 'Drama', 'immigrants', 'library vhs'},
#  {'Children', 'Comedy', 'soccer'},
#  {'Drama', 'musicians'},
#  {'Adventure', 'Children', 'Fantasy'},
#  {'Drama', 'boring', 'drama', 'lovable', 'robert downey jr'},
#  {'Comedy',
#   'Drama',
#   'Romance',
#   'corvallis library',
#   'italian bittersweet romance',
#   'italian love story',
#   'on disc',
#   'pablo neruda',
#   'poetry',
#   'poetry primer',
#   'sicily',
#   'troisi',
#   'writing'},
#  {'1.5', 'Drama', 'Mystery'},
#  {'Adventure', 'Children', 'Fantasy', 'magic'},
#  {'Drama', 'Thriller'},
#  {'Drama',
#   'a great homage to great teachers who educate through living what they think and feel.',
#   'emotion',
#   'glenne headly',
#   'high school',
#   'inspirational',
#   'jay thomas',
#   'moving',
#   'mrs. dewinter',
#   'music',
#   'olympia dukakis',
#   'overrated',
#   'richard dreyfuss',
#   'sappy',
#   'seen more than once',
#   'stupid',
#   'teacher',
#   'teacher as protagonist',
#   'tearful',
#   'william h. macy'},
#  {'Comedy',
#   'Crime',
#   'funny when your 10. less funny when your not.',
#   'wayans brothers'},
#  {'Comedy', 'Romance'},
#  {'Comedy',
#   'buddy comedy',
#   "can't remember",
#   'golden raspberry (worst actor)',
#   'polly shore',
#   'stupid',
#   'stupid movie'},
#  {'Action', 'Sci-Fi', 'Thriller', 'crap', 'imdb bottom 100'},
#  {'Drama', 'hw drama'},
#  {'Comedy', 'Romance', 'nudity (full frontal - notable)', 'vhs'},
#  {'Comedy', 'friendship', 'ice cube', 'wired 50 greatest soundtracks'},
#  {'Action',
#   'Comedy',
#   'Horror',
#   'Thriller',
#   'bar',
#   'bats',
#   'bikers',
#   'bouncer',
#   'brothers',
#   'campy',
#   'cult film',
#   'danny trejo',
#   'diablo',
#   "didn't finish",
#   'frontier',
#   'great use of music',
#   'hostage',
#   'intense',
#   'mexico',
#   'motorhome',
#   'nudity (topless - brief)',
#   'on the road',
#   'own',
#   'perverted',
#   'preacher',
#   'quentin tarantino',
#   'robert rodriguez',
#   'see planet terror',
#   'seen at the cinema',
#   'sex offender',
#   'snake',
#   'snakes',
#   "so bad it's good",
#   'splatter',
#   'strippers',
#   'tarantino',
#   'tattoo',
#   'terrible ending',
#   'vampire',
#   'vampires',
#   'violence',
#   'whip'},
#  {'Action', 'nudity (topless)'},
#  {'Comedy',
#   'Drama',
#   'bad whit stillman',
#   'coming-of-age',
#   'literate',
#   'talky',
#   'underrated',
#   'understated',
#   'whit stillman',
#   'whit stillman meets diner',
#   'wistful',
#   'witty',
#   'wry'},
#  {'Drama', 'War'},
#  {'Drama',
#   'Romance',
#   'bit too sweet',
#   'girlie movie',
#   'mary stuart masterson',
#   'romance'},
#  {'Comedy', 'Drama', 'golden raspberry (worst actor)'},
#  {'Action',
#   'Sci-Fi',
#   'Thriller',
#   'artificial intelligence',
#   'nudity (topless)',
#   'philip k. dick',
#   'post apocalyptic'},
#  {'Documentary'},
#  {'Drama', 'jack nicholson', 'nudity (topless)', 'sean penn'},
#  {'Drama', 'Thriller', 'nudity (topless)'},
#  {'Children',
#   'Drama',
#   'children',
#   'cultural customs and traditions',
#   'different',
#   'girl',
#   'goldfish',
#   'lost classic',
#   'money',
#   "new year's eve",
#   'on dvr',
#   'shop (establishment)',
#   'sibling relationships',
#   'snake',
#   'soldier',
#   'tailor',
#   'tehran'},
#  {'23-5-2007',
#   'Crime',
#   'Drama',
#   'Romance',
#   'buscemi',
#   'colorado',
#   'detroit',
#   'own',
#   'recommendz top pick',
#   'underrated'},
#  {'2.5',
#   'Comedy',
#   'Drama',
#   'intellectual',
#   'nudity (full frontal)',
#   'oscar (best foreign language film)',
#   'sad but good',
#   'strong woman',
#   'toronto film festival winner',
#   'toronto film festival winner 1995'},
#  {'3', 'Drama'},
#  {'Comedy', 'Drama'},
#  {'19th century',
#   'Drama',
#   'Romance',
#   'a. s. byatt',
#   'adaptation',
#   'nudity (full frontal - notable)',
#   'to see',
#   'victorian'},
#  {'Adventure',
#   'Drama',
#   'educational',
#   'history',
#   'ridley scott',
#   'storm',
#   'white squall'},
#  {'Children', 'Comedy'},
#  {'Comedy',
#   'chris farley',
#   'comedy',
#   'easily confused with other movie(s) (title)',
#   'not bad.',
#   'snl'},
#  {'Action',
#   'Thriller',
#   'christopher walken',
#   'johnny depp',
#   'suspense',
#   'synchronic'},
#  {'Drama'},
#  {'Drama',
#   'Horror',
#   'Thriller',
#   "can't remember",
#   'jekyll and hyde',
#   'john malkovich',
#   "what is with robert's bangs in this movie?! grr"},
#  {'Comedy', 'Romance', 'angela bassett'},
#  {'Comedy', 'Drama', 'Romance', 'beautiful', 'portman', 'uma thurman'},
#  {'Action',
#   'Adventure',
#   'Thriller',
#   'action',
#   'air force',
#   'foqam',
#   'mark gordon productions',
#   'nuclear bomb',
#   'park ranger',
#   'r',
#   'scope',
#   'utah',
#   'want',
#   'watch'},
#  {'Comedy', 'Drama', 'theater'},
#  {'3.5',
#   'Drama',
#   'amazing!',
#   'angry',
#   'biting',
#   'black and white',
#   'bleak',
#   'cannes: best director',
#   'co-production',
#   'confrontational',
#   'cynical',
#   'disturbing',
#   'drugs',
#   'french',
#   'ghetto',
#   'imdb top 250',
#   'missing gun',
#   'ominous',
#   'paris',
#   'r',
#   'racism',
#   'riot',
#   'social commentary',
#   'still current',
#   "tumey's dvds"},
#  {'Action', 'Thriller', 'directorial debut', 'jude law', 'want to own'},
#  {'Documentary'},
#  {'Drama', 'Thriller', 'own', 'politics'},
#  {'Adventure',
#   'Comedy',
#   'Crime',
#   'Romance',
#   'bill murray',
#   'crime',
#   'deadpan',
#   'directorial debut',
#   'dvd-video',
#   'humorous',
#   'need to own',
#   'nothing goes right',
#   'off-beat comedy',
#   'owen wilson',
#   'quirky',
#   'rent',
#   'seen more than once',
#   'sibling relationships',
#   'sweet',
#   'talky',
#   'texas',
#   'theater',
#   'to-rent',
#   'tv',
#   'unlikely criminals',
#   'wes anderson',
#   'wistful'},
#  {'Comedy'},
#  {'Mystery', 'Sci-Fi', 'Thriller', 'forgettable'},
#  {'Comedy',
#   'adam sandler',
#   'divx1',
#   'filmed in bc',
#   'foqam',
#   'golf',
#   'haha',
#   'hayao miyazaki',
#   'hockey',
#   'recommendz top pick',
#   'seen more than once',
#   'setting:golf course',
#   'sport:golf',
#   'sports',
#   'test tag',
#   "you're gonna die clown"},
#  {'Drama',
#   'Romance',
#   'adapted from:book',
#   'based on a book',
#   'book',
#   'chick flick',
#   'deliberate',
#   'heartwarming',
#   'lyrical',
#   'owned',
#   'sentimental',
#   'tearjerking',
#   'warm',
#   'wistful'},
#  {'Comedy', 'Drama'},
#  {'Adventure',
#   'Children',
#   'Comedy',
#   'Musical',
#   'based on a book',
#   'bill connolly',
#   'david goelz',
#   'franchise',
#   'jennifer saunders',
#   'muppets',
#   'pirates',
#   'steve whitmire',
#   'talking animals',
#   'tim curry'},
#  {'Documentary'},
#  {'Comedy'},
#  {'1',
#   'Action',
#   'Drama',
#   'War',
#   'a very touching movie. great role played by mel gibson as william wallace',
#   'action',
#   'adult',
#   'adventure',
#   'afi 100 (cheers)',
#   'afi 100 (thrills)',
#   'best movie ever made',
#   'best war films',
#   'biography',
#   'biopic',
#   'bloodshed',
#   'breathtaking',
#   'brutal',
#   'bullshit history',
#   'cavalry charge',
#   'classic',
#   'divx',
#   "don't remember",
#   'drama',
#   'dvd',
#   'dvd-video',
#   'earnest',
#   'england',
#   'epic',
#   "eric's dvds",
#   'evangelical',
#   'forceful',
#   'freedom',
#   'gibson',
#   'great action and tear jeker',
#   'great movie',
#   'guerra',
#   'hero',
#   'historical',
#   'history',
#   'imdb top 250',
#   'inspiration',
#   'kilts',
#   'lavish',
#   'loved it',
#   'medieval',
#   'mel gibson',
#   'mel gibson down grade',
#   'movie for the kids',
#   'nudity (topless)',
#   'oscar',
#   'oscar (best cinematography)',
#   'oscar (best directing)',
#   'oscar (best picture)',
#   'oscar winner',
#   'overrated',
#   'owned',
#   'passionate',
#   'period',
#   'poignant',
#   'revenge',
#   'sad part quite shocking',
#   'scotland',
#   'shit on a stick',
#   'so romantic.',
#   'stirring',
#   'sweeping',
#   'sword fight',
#   'tribal',
#   "tumey's dvds",
#   'violent',
#   'visceral',
#   'visual',
#   'want',
#   'want to see again',
#   'war'},
#  {'5 stars',
#   'Crime',
#   'Drama',
#   'Thriller',
#   'afi #47',
#   'afi 100',
#   'afi 100 (movie quotes)',
#   'afi 100 (thrills)',
#   'anomie',
#   'anti-hero',
#   'assassination',
#   'assassination plots',
#   'atmospheric',
#   'best performance:  robert de niro as travis bickle',
#   'best picture',
#   'bfi classic',
#   'bibliothek',
#   'boring!',
#   'cameo:martin scorsese',
#   "can't remember",
#   'cinematographer:michael chapman',
#   'city life',
#   'classic',
#   'cult film',
#   'deconstructive',
#   'deniro',
#   'disturbing',
#   'do zassania',
#   'dvd',
#   'film theory & criticism',
#   'forceful',
#   'going postal',
#   'golden palm',
#   'grim',
#   'harvey keitel',
#   'imdb top 250',
#   'insane',
#   'j netflix',
#   'jodie foster',
#   'killer-as-protagonist(?)',
#   'lurid',
#   'martin scorsese',
#   'menacing',
#   'national film registry',
#   'neo-noir',
#   'new york',
#   'new york city',
#   'obsessive quests',
#   'ohsoso',
#   'oscar nominee: best picture',
#   'paranoid',
#   'peter boyle',
#   'prostitutes',
#   'psychopath',
#   'psychopath as hero',
#   'robert de niro',
#   'scorcese',
#   'setting:nyc',
#   'slow',
#   'taxi driver',
#   "tumey's dvds",
#   "tumey's to see again",
#   'unrequited love',
#   'very good thriller',
#   'vigilantism',
#   'vigilatism',
#   'visceral'},
#  {'Action',
#   'Adventure',
#   'Comedy',
#   'Crime',
#   'bad dub',
#   'hong kong',
#   'india',
#   'jackie chan',
#   'kung fu',
#   'kung-fu',
#   'martial arts',
#   'mixed marriage',
#   'rutger hauer'},
#  {'Drama', 'Mystery'},
#  {'Drama', 'less than 300 ratings'},
#  {'Comedy'},
#  {'2.5',
#   'Documentary',
#   'anti-semitism',
#   'archive footage',
#   'bbc produced',
#   'biography',
#   'holocaust',
#   'oscar (best documentary feature)',
#   'oscar:documentary',
#   'pg',
#   'the shoah',
#   'true story'},
#  {'Crime', 'Drama', 'disturbing'},
#  {'Comedy', 'Romance'},
#  {'Comedy'},
#  {'Drama'},
#  {'Drama', 'based on a true story', 'child abuse'},
#  {'Comedy', 'Romance', "can't remember", 'dating', 'nudity (topless - brief)'},
#  {'Drama',
#   'Mystery',
#   'Romance',
#   'airport',
#   'amelie-esque',
#   'birthday',
#   'breakups and divorces',
#   'brief encounters',
#   'cops',
#   'dreamlike',
#   'excellent',
#   'fanciful',
#   'foggy',
#   'good music',
#   'hong kong',
#   'hongkong',
#   'indians',
#   'ironic',
#   'jogging',
#   'jukebox',
#   'library vhs',
#   'loneliness',
#   'lyrical',
#   'may 1',
#   'melancholy',
#   'mistaken identities',
#   'movielens quickpick',
#   'nan',
#   'narrated',
#   'nocturnal',
#   'obsession',
#   'on dvr',
#   'opposites attract',
#   'pineapple',
#   'reflective',
#   'smuggling',
#   'stewardess',
#   'stylized',
#   'sunglasses',
#   'ticket',
#   'time',
#   'urbane',
#   'very good',
#   'wong kar wai'},
#  {'Drama'},
#  {'Comedy',
#   'nudity (topless - brief)',
#   'screwball comedy',
#   'want to see again'},
#  {'Adventure', 'Children', 'Fantasy'},
#  {'Drama'},
#  {'Documentary'},
#  {'Comedy', 'Romance', 'nudity (topless - notable)'},
#  {'Drama'},
#  {'Drama', 'Romance'},
#  {'Thriller',
#   'flop',
#   'nudity (rear)',
#   'nudity (topless - brief)',
#   'san francisco',
#   'screenwriter:joe eszterhas'},
#  {'Comedy', 'Drama'},
#  {'Documentary', 'illegal art'},
#  {'Comedy',
#   'bruce dern',
#   'good comedy',
#   'harland williams',
#   'harry dean stanton',
#   'kelsey grammer',
#   'lauren holly',
#   'rebel commander',
#   'renegade crew',
#   'rip torn',
#   'rob scheider',
#   'rusty sub',
#   'submarine',
#   'u.s. navy submarine',
#   'william h. macy'},
#  {'Documentary', 'documentary', 'tragedy'},
#  {'Documentary'},
#  {'Drama'},
#  {'Action', 'Drama'},
#  {'Drama', 'Romance', 'afternoon section', 'bibliothek', 'journalism'},
#  {'Comedy',
#   'adapted from:play',
#   "can't remember",
#   'comedy',
#   'crossdressing',
#   'gay',
#   'gene hackman',
#   'homosexual theme',
#   'homosexuality',
#   'madonna',
#   'queer?',
#   'remakeof:la cage aux folles (1978)',
#   'robin williams',
#   'watch-fully'},
#  {'Drama'},
#  {'Drama'},
#  {'Comedy', 'family', 'irish'},
#  {'Action',
#   'action',
#   'bad movie',
#   'buddy movie',
#   'bã¶se jungs',
#   'car chase',
#   'directorial debut',
#   'easily confused with other movie(s) (title)',
#   'just for fun.',
#   'matrin lawrecne',
#   'michael bay',
#   'will smith'},
#  {'Adventure', 'Children'},
#  {'Drama',
#   'based on a true story',
#   'book',
#   'catholicism',
#   'diary',
#   'drugs',
#   'escape',
#   'expelled from school',
#   'heroin',
#   'leonardo dicaprio',
#   'male nudity',
#   'male prostitute',
#   'masturbation',
#   'mother-son relationship',
#   'new york city',
#   'on dvr',
#   'prostitutes',
#   'school',
#   'teacher student relationship',
#   'very good',
#   "writer's life"},
#  {'Drama', 'nudity (topless - notable)'},
#  {'Crime',
#   'Drama',
#   'Thriller',
#   'amnesia',
#   'cerebral',
#   'deliberate',
#   'haunted by the past',
#   'humorous',
#   'interesting',
#   'literate',
#   'quirky',
#   'redemption',
#   'stylized',
#   'unlikely friendships',
#   'whimsical'},
#  {'Adventure',
#   'Drama',
#   'afi 100 (cheers)',
#   'afi 100 (movie quotes)',
#   'almost favorite',
#   'astronauts',
#   'based on a book',
#   'based on a true story',
#   'biographical',
#   'catastrophe',
#   'claustrophobic',
#   'clv',
#   'did i see it?',
#   'disaster',
#   'dislike tom hanks',
#   'drama',
#   'drive in',
#   'dvd',
#   'earnest',
#   'ed harris',
#   'formulaic',
#   'good movie',
#   'historical',
#   'history',
#   'interesting',
#   'kevin bacon is a beast',
#   'matter-of-fact',
#   'moon',
#   'nasa',
#   'need to own',
#   'nostalgic',
#   'oscar (best editing)',
#   'oscar (best sound)',
#   'outer space',
#   'owned',
#   'ron howard',
#   'see: in the shadow of the moon',
#   'seen 2008',
#   'seen more than once',
#   'setting:space/earth orbit',
#   'space',
#   'space program',
#   'suspense',
#   'tense',
#   'tom hanks',
#   'tom hanks is great',
#   'true story',
#   'want',
#   'watch-again',
#   'we have a problem'},
#  {'Action',
#   'Drama',
#   'Romance',
#   'War',
#   'atmospheric',
#   "can't remember",
#   'earthy',
#   'hulu',
#   'literate',
#   'one of my favorites',
#   'passionate',
#   'rape',
#   'rousing',
#   'sweeping',
#   'sword fighting',
#   'tense',
#   'tribal',
#   'violent',
#   'watch'},
#  {'Drama',
#   'Horror',
#   'christopher walken',
#   'drug abuse',
#   'philosophical',
#   'stylized',
#   'vampires'},
#  {'Action',
#   'Adventure',
#   'Comedy',
#   'Crime',
#   'action',
#   'adapted from:comic',
#   'alter ego',
#   'ammaction',
#   'bank robbery',
#   'batman',
#   'batman (series)',
#   'comic book',
#   'dc',
#   'dc comics',
#   'ei muista',
#   'franchise',
#   'jim carrey',
#   'nicole kidman',
#   'seen at the cinema',
#   'sequel',
#   'super-hero',
#   'superhero',
#   'tommy lee jones',
#   'want',
#   'watch-again',
#   'watched 1995'},
#  {'Drama',
#   'best performance:  catherine deneuve as severine serizy',
#   'bunuel',
#   'clv',
#   'double life',
#   'drama',
#   'enigmatic',
#   'extramarital affairs',
#   'library vhs',
#   'nudity (rear)',
#   'ohsoso',
#   'prostitutes',
#   'satirical',
#   'sexy',
#   'stylized',
#   'the best of',
#   'witty',
#   'wry'},
#  {'Adventure', 'Drama', 'War', 'history', 'wonderful surprise movie'},
#  {'Comedy', 'Drama', 'minimalist', 'nudity (topless)', 'plotless'},
#  {'Comedy', 'War', 'conspiracy'},
#  {'Adventure',
#   'Children',
#   'adapted from:comic',
#   'brad silberling',
#   'children',
#   'christina ricci',
#   'family',
#   'ghost',
#   'ghosts',
#   'kid flick',
#   'nice'},
#  {'Crime', 'Drama', 'Mystery'},
#  {'?adapted from:book',
#   'Action',
#   'Adventure',
#   'Mystery',
#   'Sci-Fi',
#   'author:michael chricton?',
#   'based on a book',
#   'gorillas',
#   'michael crichton'},
#  {'Drama',
#   'Thriller',
#   'War',
#   'clearplay',
#   'clv',
#   'denzel washington',
#   'gene hackman',
#   'jason robards',
#   'own',
#   'r',
#   'submarine',
#   'viggo mortensen',
#   'want',
#   'war'},
#  {'Documentary',
#   'biographical',
#   'cynical',
#   'deliberate',
#   'disturbing',
#   'documentary',
#   'fucked up',
#   'in netflix queue',
#   'irreverent',
#   'netflixq',
#   'qube',
#   'quirky',
#   'raunchy',
#   'sexual',
#   'wry'},
#  {'Action',
#   'Romance',
#   'Thriller',
#   'action',
#   'austin too hip',
#   'crime',
#   'danny trejo',
#   "eric's dvds",
#   'gfei own it',
#   'mexico',
#   'nudity (topless - brief)',
#   'organized crime',
#   'rame euy',
#   'robert rodriguez',
#   'romance',
#   'sequel',
#   'thriller',
#   "tumey's dvds",
#   'violence'},
#  {'Crime',
#   'Film-Noir',
#   'Mystery',
#   'Thriller',
#   'atmospheric',
#   'cheadle appearance',
#   "denzel's fine behind",
#   'femmes fatales',
#   'film noir',
#   'moody',
#   'noir thriller',
#   'nostalgic',
#   'private eyes',
#   'r',
#   'race relations',
#   'stylized',
#   'suspense',
#   'understated'},
#  {'Action',
#   'Crime',
#   'Thriller',
#   'action',
#   'afternoon section',
#   "always watch it when it's on tv",
#   'bmf',
#   'bruce willis',
#   'but no way as good as the other two',
#   'crime',
#   'divx',
#   "eric's dvds",
#   'good',
#   'more explosions',
#   'own',
#   'predictable',
#   'samuel l. jackson',
#   'seen at the cinema',
#   'terrorism',
#   'thriller',
#   "tumey's dvds",
#   'violent',
#   'want',
#   'watched 1995'},
#  {'Comedy', 'Crime', 'Drama', 'shock and truth'},
#  {'Drama', 'last words connection'},
#  {'Action',
#   'Drama',
#   'Romance',
#   'chick flick',
#   'julia ormond',
#   'king arthur',
#   'richard gere',
#   'romance',
#   'sean connery',
#   'war'},
#  {'Adventure', 'Children', 'Drama', 'adventure', 'animal:whale'},
#  {'Action',
#   'Adventure',
#   'Crime',
#   'Thriller',
#   'action',
#   'alter ego',
#   'angelina jolie',
#   'anjelina',
#   'awesome soundtrack',
#   'bechdel test:fail',
#   'boring',
#   'computer cracker',
#   'computers',
#   'cool videogame (scene)',
#   'cult film',
#   'cyber-blackmail/intimidation',
#   'cyber-intimidation',
#   'decent',
#   'die like the rest',
#   'geeks on screen',
#   'hacker',
#   'hackers',
#   'hacking',
#   'hilarity',
#   'inaccurate',
#   'internet',
#   'lame',
#   'mess with the best',
#   'nudity (topless - brief)',
#   'video games'},
#  {'Comedy', 'Drama', 'aids', 'friendship relations', 'gay'},
#  {'Action',
#   'Sci-Fi',
#   'Thriller',
#   'adapted from:author',
#   'book was better',
#   'cyberpunk',
#   'dvd',
#   'dystopia',
#   "erlend's dvds",
#   'hackers',
#   'katsomattomat',
#   'keanu reeves',
#   'memory',
#   'sci-fi',
#   'takeshi kitano'},
#  {'?android(s)/cyborg(s)',
#   'Action',
#   'Crime',
#   'Sci-Fi',
#   "can't remember",
#   'comic book',
#   'dystopia',
#   'futuristmovies.com',
#   "not really interested'",
#   'police',
#   'stallone',
#   'sylvester stallone',
#   'want',
#   'what is this'},
#  {'Comedy', 'golden raspberry (worst actor)', 'tacos'},
#  {'Drama',
#   'aids',
#   'directorial debut',
#   'drugs',
#   "eric's dvds",
#   'hw drama',
#   'my movies',
#   'new york city',
#   'nudity (full frontal)',
#   'owned',
#   'teenagers',
#   'very interesting',
#   'youth gone wild'},
#  {'Comedy',
#   'behind-the-scenes',
#   'dwarf',
#   'film-making',
#   'indie',
#   'meta-indie',
#   'nudity (topless)'},
#  {'Horror', "can't remember", 'huh?'},
#  {'Comedy',
#   'Drama',
#   'adapted from:play',
#   'dark comedy',
#   'psychic character',
#   'serial killer'},
#  {'Drama', 'Romance', 'nudity (topless - brief)'},
#  {'1990s',
#   'Comedy',
#   'clearplay',
#   'comic books',
#   'crude humor',
#   'do kupienia',
#   'ensemble',
#   'good dialogue',
#   'hilarious',
#   'jason lee',
#   'jay and silent bob',
#   "karrin's favorite",
#   'kevin smith',
#   'malos tratos',
#   'nudity (topless)',
#   'one day',
#   'own',
#   'r',
#   'seen more than once',
#   'still behind chasing amy.',
#   'teen',
#   'teen angst',
#   'view askew',
#   'way better than dogma or jersey girl'},
#  {'Action', 'Children', 'action', 'no rec?'},
#  {'Drama', 'Romance'},
#  {'Comedy', 'Horror', 'Thriller', 'moscow', 'mute', 'russia'},
#  {'2', 'Drama'},
#  {'Action',
#   'Crime',
#   'Thriller',
#   'action',
#   'computer cracker',
#   'computers',
#   'crime',
#   'cyber-blackmail/intimidation',
#   'cyber-intimidation',
#   'dennis miller',
#   'diane baker',
#   'hackers',
#   'hacking',
#   'internet',
#   'irwin winkler',
#   'jeremy northam',
#   'ken howard',
#   'praetorians',
#   'sandra bullock',
#   'thriller',
#   'wendy gazelle'},
#  {'Comedy',
#   'Romance',
#   'afternoon section',
#   "can't remember",
#   'cheesy',
#   'chick flick',
#   'chris columbus',
#   'comedy',
#   'funny',
#   'good romantic comedies',
#   'hilarious',
#   'hugh grant',
#   'humor',
#   'jeff goldblum',
#   'joan cusack',
#   'julianne moore',
#   'meh',
#   'nice',
#   'pregnancy',
#   'robin williams',
#   'romance',
#   'romantic comedy',
#   'tom arnold'},
#  {'Comedy',
#   'bechdel test:pass',
#   'coming-of-age',
#   'hw comedy',
#   'librarians',
#   "protagonist is `party girl'",
#   'setting:library',
#   'underrated'},
#  {'Fantasy',
#   'Horror',
#   'Mystery',
#   'best devil ever',
#   'christopher walken',
#   'jonossa',
#   'slashy'},
#  {'Comedy', 'Fantasy', 'unreal'},
#  {'Thriller',
#   'environment',
#   'facebook rec',
#   'food',
#   'interesting effort',
#   'stark'},
#  {'Drama', 'Romance', 'gary oldman', 'trash'},
#  {'Documentary'},
#  {'Drama',
#   'campy',
#   'cult film',
#   'cynical',
#   "dancer's life",
#   'faltering friendships',
#   'golden raspberry (worst actress)',
#   'golden raspberry (worst picture)',
#   'lurid',
#   'nc-17',
#   'nudity (full frontal - notable)',
#   'paul verhoeven',
#   'raunchy',
#   'rise and fall stories',
#   'self-destructive romance',
#   'sexual',
#   'strippers',
#   'watched it for the boobs'},
#  {'Comedy',
#   'Drama',
#   'ensemble cast',
#   'father son relationship',
#   'forest whitaker',
#   'good',
#   'harvey keitel',
#   'interesting',
#   'mike super recs',
#   'multiple storylines',
#   'new york city',
#   'newyork',
#   'owned',
#   'small business'},
#  {'Comedy', 'Drama', 'Romance'},
#  {'Horror',
#   'Sci-Fi',
#   'futuristmovies.com',
#   'nudity (topless - notable)',
#   'nudity (topless)',
#   'seen at the cinema'},
#  {'Drama'},
#  {'Action',
#   'Crime',
#   'Drama',
#   'Mystery',
#   'Sci-Fi',
#   'Thriller',
#   'alcohol consume',
#   'angela bassett',
#   'cyberpunk',
#   'dark',
#   'future',
#   'futuristic',
#   'futuristmovies.com',
#   'gay',
#   'hh',
#   'jonossa',
#   'junk',
#   'memory',
#   'mindfuck',
#   'mystic',
#   'new year 1999',
#   'not seen',
#   'nudity (topless)',
#   'ralph fiennes',
#   'sci-fi',
#   'seen at the cinema',
#   'smoking',
#   'strange',
#   'virtual reality'},
#  {'Drama',
#   'Musical',
#   'bittersweet',
#   'catherine deneuve',
#   'corvallis library',
#   'facebook rec',
#   'french',
#   'golden palm',
#   'lavish',
#   'lyrical',
#   'made me cry',
#   'musical',
#   'nino castelnuovo',
#   'on dvr',
#   'passionate',
#   'stylized',
#   'sweet',
#   'vday',
#   'wistful'},
#  {'Thriller'},
#  {'1950s',
#   'Drama',
#   "can't remember",
#   'korean war',
#   'little league',
#   'widows/widowers'},
#  {'Drama', 'Romance', 'david thewlis', 'great direction', 'leonardo dicaprio'},
#  {'Comedy',
#   'appreciating diversity',
#   'crossdressing',
#   'hugo weaving',
#   'queer',
#   'road trip',
#   'transsexuals'},
#  {'Action', 'steven seagal'},
#  {'Comedy', 'Drama', 'john turturro'},
#  {'Documentary'},
#  {'Drama', 'Romance', 'cinematography', 'keanu reeves', 'romance'},
#  {'Action',
#   'Adventure',
#   'Sci-Fi',
#   'apocalypse',
#   'better than everybody thinks',
#   'big budget',
#   "can't remember",
#   'dennis hopper',
#   'expensive',
#   'friday night movie',
#   'futuristmovies.com',
#   'gyrocopter',
#   'horrible',
#   'kevin costner',
#   'post apocalypse',
#   'sci-fi',
#   'search',
#   'seen at the cinema',
#   'sf',
#   'smeat',
#   'stupid',
#   'tetris',
#   'very boring',
#   'watch',
#   'x-mas movie'},
#  {'Drama'},
#  {'Western'},
#  {'Drama'},
#  {'Adventure', 'Comedy', 'Crime', 'Mystery'},
#  {'Drama',
#   'hw foreign',
#   'library',
#   'not corv lib',
#   'oscar (best foreign language film)',
#   'russian',
#   'russian communist tragedy'},
#  {'Drama',
#   'War',
#   'awful',
#   'bloody',
#   'criterion',
#   'gory',
#   'hard to watch',
#   'harrowing',
#   'horror of war',
#   'non-linear',
#   'to see'},
#  {'(s)vcd',
#   'Drama',
#   'Romance',
#   'americans abroad',
#   'bibliothek',
#   'brief encounters',
#   'buy',
#   'castle rock',
#   'clearplay',
#   'conversation',
#   'dialogue',
#   'dvd-video',
#   'ethan hawke',
#   'facebook rec',
#   'fascinating how a conversation and two people keep you interested',
#   'favorite',
#   'generation x',
#   'girlie movie',
#   'julie delpy',
#   'library',
#   'literate',
#   'minimalist',
#   'must see',
#   'need to own',
#   'poignant',
#   'r',
#   'really romantic',
#   'reflective',
#   'reminded me of thoughts i had when i was that age',
#   'seen more than once',
#   'special',
#   'subscription',
#   'talky',
#   'trains',
#   'twentysomething life',
#   'understated',
#   'urbane',
#   'vacation romances',
#   'vienna',
#   'will there be another?',
#   'wistful',
#   'witty'},
#  {'Comedy',
#   'adam sandler',
#   'funniest movies',
#   'school',
#   'seen more than once',
#   'stop looking at me swan',
#   'theater',
#   'tv',
#   'vhs'},
#  {'Drama', 'Thriller'},
#  {'Comedy',
#   'Drama',
#   'nudity (topless - notable)',
#   'road movie',
#   "women's lib"},
#  {'Drama'},
#  {'Horror', 'h.p. lovecraft'},
#  {'Drama', 'Romance', 'chick flick', 'high school', 'ireland', 'irish'},
#  {'4',
#   'Comedy',
#   'bad acting',
#   'black and white',
#   'charmingly amateurish',
#   'convenience store',
#   'crude humor',
#   'cynical',
#   'dialogue driven',
#   'directorial debut',
#   'do kupienia',
#   'generation x',
#   'get',
#   'good dialogue',
#   'hard to rate',
#   'hilarious',
#   'hilarity',
#   'hillarious',
#   "i'm not even supposed to be here today",
#   'irreverent',
#   'kevin smith',
#   'literate',
#   'low budget',
#   'matter-of-fact',
#   "men's friendships",
#   'minimalist',
#   'must see',
#   'new jersey',
#   'one day',
#   'own',
#   'pitã¤s kai jaksaa kattoa',
#   'quirky',
#   'rent',
#   'seen 2006',
#   'seen more than once',
#   'slackers',
#   'surreal',
#   'talky',
#   'theater',
#   'to see',
#   'true to life',
#   "tumey's dvds",
#   'twentysomething life',
#   'view askew',
#   'witty',
#   'work ethics',
#   'workplace',
#   'wry'},
#  {'Comedy',
#   'Drama',
#   'Romance',
#   'afternoon section',
#   "can't remember",
#   'fantasy',
#   'johnny depp',
#   'madness',
#   'marlon brando',
#   'mental illness',
#   'nudity (rear)',
#   'passion',
#   'psychology',
#   'romance'},
#  {'Drama',
#   'Thriller',
#   'based on a book',
#   "can't remember",
#   'michael crichton'},
#  {'Thriller'},
#  {'Action', 'Thriller', "can't remember"},
#  {'Comedy'},
#  {'Drama', 'Thriller', 'nudity (topless - notable)', 'roman polanski'},
#  {'Drama',
#   'Thriller',
#   'adapted from:book',
#   'book',
#   "can't remember",
#   'child abuse',
#   'drama',
#   'horror',
#   'housekeeper',
#   'incest',
#   'kathy bates',
#   'stephen king'},
#  {'Comedy',
#   'buddy movie',
#   'carey',
#   'comedy',
#   'fantastic!',
#   'funniest film ever',
#   'funny as hell',
#   'get',
#   'goofy',
#   'hilarious',
#   'infantile',
#   'irreverent',
#   'jeff daniels',
#   'jim carrey',
#   'madcap',
#   'most annoying sound?',
#   'not funny',
#   'own',
#   'quirky',
#   'raunchy',
#   'shit!!',
#   'silly',
#   "so dumb it's funny",
#   'stupid',
#   'theater',
#   'tv',
#   'very funny',
#   'vhs'},
#  {'Comedy',
#   'Drama',
#   'Romance',
#   'aging',
#   'airline company',
#   'breakups and divorces',
#   'buddhism',
#   'chefs',
#   'christening',
#   'christians',
#   'cooking',
#   'corvallis library',
#   'dvd-video',
#   'family gatherings',
#   'fast food',
#   'father daughter relationship',
#   'food',
#   'food/cooking',
#   'haunting endings',
#   'in netflix queue',
#   'karaoke',
#   'letters',
#   'library vhs',
#   'makes you hungry',
#   'marriage',
#   'minimalist',
#   'photography',
#   'remade',
#   'remade into tortilla soup',
#   'remadeas:tortilla soup',
#   'remakeof:eat drink man woman',
#   'restaurant',
#   'rival suitor',
#   'school',
#   'see: bella martha',
#   'sister sister relationship',
#   'slow food',
#   'tasteful',
#   'teacher',
#   'volleyball',
#   'widows/widowers',
#   'workplace'},
#  {'Drama',
#   'canada',
#   'death',
#   'dvd-video',
#   'gay',
#   'mystery',
#   'nudity (topless - notable)',
#   'obsession',
#   'romance',
#   'see twice',
#   'smuggling',
#   'strippers',
#   'to see',
#   'toronto',
#   'widower'},
#  {'Comedy',
#   'nudity (full frontal - notable)',
#   'rosie in leather',
#   'sexuality:bdsm'},
#  {'Comedy',
#   'Drama',
#   'affectionate',
#   'bella lugosi',
#   'biography',
#   'biopic',
#   'black and white',
#   'dark dramedy',
#   'dvd',
#   'edith wharton',
#   'elegiac',
#   'film noir',
#   'gentle',
#   'imdb top 250',
#   'johnny depp',
#   'kurosawa',
#   'movie business',
#   'oscar (best supporting actor)',
#   'owned',
#   'plan 9',
#   'poignant',
#   'quirky',
#   'tim burton',
#   'underappreciated',
#   'underrated piece of genius',
#   'witty'},
#  {'Action',
#   'Comedy',
#   'Romance',
#   'comedy',
#   'fear of airplanes',
#   'girlie movie',
#   'marriage',
#   'meg ryan',
#   'paris scenery',
#   'romance',
#   'tasse de chocolat'},
#  {'4',
#   'Comedy',
#   'Romance',
#   'basketball',
#   'boring',
#   'debra winger',
#   "erlend's dvds",
#   'france',
#   'infertility',
#   'nice',
#   'ordinary',
#   'paris'},
#  {'Adventure', 'Children'},
#  {'Animation',
#   'Children',
#   'Comedy',
#   'Romance',
#   'disney',
#   'disney animated feature',
#   'father-son relationship',
#   'generation gap',
#   'goofy',
#   'katottava',
#   'road trip'},
#  {'Thriller', 'based on a book', 'dean koontz'},
#  {'Children', 'Drama'},
#  {'18th century', 'Drama', 'Musical', 'backstage', 'musical', 'opera', 'sad'},
#  {'Comedy'},
#  {'Animation', 'Children'},
#  {'Crime', 'Drama'},
#  {'Documentary',
#   'basketball',
#   'basketball documentary',
#   'chicago',
#   'documentary',
#   'e',
#   'high school',
#   'hulu',
#   'library vhs',
#   'movie to see',
#   'national film registry',
#   'nba',
#   'on dvr',
#   'poverty',
#   'school',
#   'setting:chicago',
#   'sport:basketball',
#   'sports',
#   'true story'},
#  {'Crime',
#   'Drama',
#   'Fantasy',
#   'Romance',
#   'Thriller',
#   'adolescent fantasy',
#   'australia',
#   'based on a true story',
#   'bizarre',
#   'boring',
#   'coming of age',
#   'crazy',
#   'disturbing',
#   'dvd',
#   'fantasy life',
#   'homo-erotic',
#   'kate winslet',
#   'lesbian',
#   'lgbt',
#   'new zealand',
#   'nudity (topless)',
#   'opposites attract',
#   'passionate',
#   'peter jackson',
#   'poignant',
#   'queer',
#   'redemption',
#   'romance',
#   'scope',
#   'sexual awakening',
#   'stylized',
#   'surreal',
#   'surrealism',
#   'troy library',
#   'visceral',
#   'wistful'},
#  {'Comedy', 'bad', 'sinbad'},
#  {'Drama',
#   'Romance',
#   'beautiful music',
#   'beethoven',
#   'biographical',
#   'character based on real person:beethoven',
#   'classical music',
#   'deafness',
#   'drama',
#   'gary oldman',
#   'nudity (full frontal)',
#   'r',
#   'to see',
#   'topic:deafness'},
#  {'Children', 'Comedy', 'nostalgic'},
#  {'Action', 'horror'},
#  {'Comedy',
#   'Romance',
#   'albert einstein',
#   'bibliothek',
#   'character based on real person:albert einstein',
#   'character based on real person:marilyn monroe',
#   'einstein',
#   'italian',
#   'meg ryan',
#   'romance',
#   'tim robbins'},
#  {'6ir6',
#   'Drama',
#   'Horror',
#   'adapted from:book',
#   'anne rice',
#   'antonio banderas',
#   'author:anne price',
#   'based on a book',
#   'book',
#   'book was better',
#   'boring',
#   'brad pitt',
#   'brad pitt and tom cruise',
#   'brilliant',
#   "can't remember",
#   'debased',
#   'dracula',
#   'drama',
#   'fantasy',
#   'horror',
#   'interviews',
#   'kirsten dunst',
#   'literature',
#   'lots of blood',
#   'mediocre plot',
#   'my dvds',
#   'my movies',
#   'neil jordan',
#   'nudity (full frontal)',
#   'spooky',
#   'stephen rea',
#   'terror',
#   'to see',
#   'tom cruise',
#   'usa',
#   'vampire',
#   'vampires',
#   'want',
#   'want to own'},
#  {'Drama'},
#  {'Comedy'},
#  {'Comedy',
#   'Sci-Fi',
#   'arnold schwarzenegger',
#   'bright',
#   'earnest',
#   'easygoing',
#   'funny',
#   'horrible',
#   'julie andrews',
#   'light',
#   'silly'},
#  {'Mystery', 'Thriller', 'court', 'wow!'},
#  {'Adventure', 'Children', 'Comedy', 'Fantasy', 'Romance', 'joss acklund'},
#  {'Crime',
#   'Drama',
#   'Thriller',
#   'nudity (topless - brief)',
#   'samuel l. jackson'},
#  {'!george lucas',
#   '70mm',
#   '70s',
#   'Action',
#   'Adventure',
#   'Sci-Fi',
#   'action',
#   'adventure',
#   'afi #15',
#   'afi 100',
#   'afi 100 (cheers)',
#   'afi 100 (movie quotes)',
#   'afi 100 (thrills)',
#   'akira kurosawa',
#   'alec guiness',
#   'alec guinnes',
#   'atmospheric',
#   'awesome soundtrack',
#   'bechdel test:fail',
#   'breakthroughs',
#   'c3po',
#   'carrie fisher',
#   'chewbacca',
#   'classic',
#   'comic book style',
#   'complete',
#   'darth vader',
#   'death star',
#   'desert',
#   'director-screenwriter',
#   'divx1',
#   'dvd',
#   'dvd1',
#   'empire',
#   'epic adventure',
#   "eric's dvds",
#   'fantasy',
#   'far future',
#   'force',
#   'franchise',
#   'futuristmovies.com',
#   'galactic',
#   'george lucas',
#   'gfei own it',
#   'great soundtrack',
#   'han solo',
#   'harrison ford',
#   'heroic mission',
#   'highly quotable',
#   'homage',
#   'hot scifi',
#   'humorous',
#   'imdb top 250',
#   'james earl jones',
#   'leia',
#   'light saber',
#   'lucas',
#   'luke',
#   'luke skywalker',
#   'mark hamill',
#   'midgets',
#   'millenium falcon',
#   'murder/fatality',
#   'myth',
#   'national film registry',
#   'nerdy',
#   'noise in space',
#   'obi wan',
#   'obi wan kenobi',
#   'oscar (best art direction - set decoration)',
#   'oscar (best costume design)',
#   'oscar (best editing)',
#   'oscar (best effects - visual effects)',
#   'oscar (best music - original score)',
#   'oscar (best sound)',
#   'overrated',
#   'peter cushing',
#   'pinnacle film',
#   'princess',
#   'quotable',
#   'r2 d2',
#   'rating very dependent on version',
#   'reluctant hero',
#   'robots',
#   'robots and androids',
#   'rousing',
#   'saturn award (best actor)',
#   'saturn award (best actress)',
#   'saturn award (best costumes)',
#   'saturn award (best director)',
#   'saturn award (best makeup)',
#   'saturn award (best music)',
#   'saturn award (best science fiction film)',
#   'saturn award (best special effects)',
#   'saturn award (best supporting actor)',
#   'saturn award (best writing)',
#   'sci-fi',
#   'seen at the cinema',
#   'seen more than once',
#   'sequel',
#   'series',
#   'space',
#   'space combat',
#   'space opera',
#   'space travel',
#   'space wars',
# ...
#   'amazing cinematography',
#   'apes portrayed as human-precursers',
#   'arthur c. clarke',
#   'artificial intelligence',
#   'atmospheric',
#   'author:arthur c. clarke',
#   'avante-garde',
#   'baffling',
#   'based on a book',
#   'benign aliens',
#   'betamax',
#   'book',
#   'boring',
#   'breakthroughs',
#   'breathtaking',
#   'cerebral',
#   'chilly',
#   'cinematographer:geoffrey unsworth',
#   'classic',
#   'clv',
#   'computer paranoia',
#   'cool but freaky',
#   'cosmic',
#   'cult film',
#   'deliberate',
#   'dvd',
#   'dvd collection',
#   'dvd-r',
#   'enigmatic',
#   "erlend's dvds",
#   'evolution',
#   'fast-forwarding overlong beginnings',
#   'future',
#   'future art deco',
#   'future dystopias',
#   'futuristmovies.com',
#   'genius',
#   'groundbreaking',
#   'hal',
#   'hal 9000',
#   'hard to rate',
#   'head movie',
#   'human versus computer',
#   'imdb top 250',
#   'kubrick',
#   'meditative',
#   'mindfuck',
#   'national film registry',
#   'ohsoso',
#   'oppressive soundtrack',
#   'oscar (best effects - visual effects)',
#   'sci-fi',
#   'setting:space/space ship',
#   'sf',
#   'slow',
#   'somber',
#   'space',
#   'space travel',
#   'spaceships',
#   'sparse',
#   'stanley kubrick',
#   'stoner movie',
#   'surreal',
#   'the film!!',
#   "tumey's dvds",
#   'uk',
#   'usa',
#   'veja',
#   'video surveillance',
#   'visionary'},
#  {'Adventure', 'Romance'},
#  {'Drama',
#   'afi #16',
#   'afi 100',
#   'afi 100 (movie quotes)',
#   'backstage',
#   'best performance:  bette davis as margo channing',
#   'best picture',
#   'bettie davis rules',
#   'bibliothek',
#   'camp',
#   'classic',
#   'dvd-r',
#   'dvd-ram',
#   'emerson must see',
#   'eva contro eva',
#   'fabulous',
#   'friends should see',
#   'gay fave',
#   'great screenplays',
#   'hollywood',
#   'imdb top 250',
#   'national film registry',
#   'oscar (best directing)',
#   'oscar (best picture)',
#   'oscar (best supporting actor)',
#   'tony awards',
#   "tumey's dvds",
#   'ummarti2006',
#   'veja',
#   'wikilens top pick'},
#  {'Comedy',
#   "adapted from b'way",
#   'chick flick',
#   'classic',
#   'divorce',
#   'national film registry'},
#  {'3',
#   'Drama',
#   'Mystery',
#   'Romance',
#   'Thriller',
#   'afi 100 (thrills)',
#   'alfred hitchcock',
#   'amazing cinematography',
#   'atmospheric',
#   'classic',
#   'criterion',
#   'dark',
#   'dark comedy',
#   'enigmatic',
#   "erlend's dvds",
#   'filmaffinity top pick',
#   'george sanders',
#   'gloomy',
#   'gothic',
#   'great adaptations',
#   'hitchcock',
#   'imdb top 250',
#   'joan fontaine',
#   'judith anderson',
#   'laurence olivier',
#   'lavish',
#   'lawrence olivier',
#   'moody',
#   'mrs. dewinter',
#   'nigel bruce',
#   'ominous',
#   'oscar (best cinematography)',
#   'oscar (best picture)',
#   'reginald denny'},
#  {'Drama',
#   'Film-Noir',
#   'Mystery',
#   'Thriller',
#   "erlend's dvds",
#   'europe',
#   'journalism',
#   'war'},
#  {'Film-Noir',
#   'Romance',
#   'Thriller',
#   'afi 100 (thrills)',
#   'alfred hitchcock',
#   'assassination',
#   'best performance:  cary grant as t.r. devlin',
#   'cary grant',
#   'claude rains',
#   'criterion',
#   'hitchcock',
#   'imdb top 250',
#   'ingrid bergman',
#   'k movie',
#   'leopoldine konstantin',
#   'louis calhern',
#   'miami',
#   'national film registry',
#   'need to own',
#   'oscar nominee: supporting actor',
#   'put me to sleep',
#   'reinhold schã¼nzel',
#   "tumey's dvds"},
#  {'2.5',
#   'Mystery',
#   'Romance',
#   'Thriller',
#   'amnesia',
#   'criterion',
#   'gregory peck',
#   'hitchcock',
#   'ingrid bergman',
#   'library',
#   'mental hospital',
#   'overture',
#   'psychoanalysis',
#   'sexual harrassment',
#   'think of the acting...'},
#  {'Romance', 'carey grant', 'classic love story', "didn't finish"},
#  {'Crime',
#   'Mystery',
#   'Romance',
#   'Thriller',
#   'adapted from:book',
#   'alfred hitchcock',
#   'cat burglar',
#   'classic',
#   'hitchcock',
#   'hw classics',
#   'murder',
#   'not corv lib',
#   'oscar (best cinematography)',
#   'oscar:cinematography',
#   'scene:rendezvous in flower market',
#   'subgenre:cat burglar'},
#  {'Comedy', 'afi 100 (laughs)', 'bibliothek', 'classic', 'remade', 'wedding'},
#  {'Comedy',
#   'Musical',
#   'astaire/kelly musical',
#   'broadway',
#   'cav',
#   'clv',
#   "erlend's dvds",
#   'national film registry',
#   'new york city',
#   'satire'},
#  {'Comedy',
#   'Romance',
#   'afi 100 (laughs)',
#   'best performance:  greta garbo as ninotchka',
#   'bibliothek',
#   'blindfold',
#   'cold war',
#   'communism',
#   'dated humour',
#   'national film registry',
#   'russia',
#   'satire'},
#  {'Comedy',
#   'Romance',
#   'almost favorite',
#   'audrey hepburn',
#   'classic love story',
#   'hw classics',
#   'not corv lib'},
#  {'*good* musicals',
#   'Musical',
#   'adapted from:play',
#   'courtesan',
#   'french theme',
#   'misogynist',
#   'musical',
#   'national film registry',
#   'oscar (best cinematography)',
#   'oscar (best directing)',
#   'oscar (best picture)',
#   'prostitution',
#   "tumey's dvds"},
#  {'Comedy', 'Drama'},
#  {'12th century',
#   'Action',
#   'Adventure',
#   'Romance',
#   'afi 100 (thrills)',
#   'archery',
#   'castle',
#   'cav',
#   'classic',
#   'clv',
#   'dvd-r',
#   'errol flynn',
#   'forest',
#   'imdb top 250',
#   'medieval',
#   'movie to see',
#   'myth',
#   'national film registry',
#   'outlaw',
#   'swashbuckler'},
#  {'Adventure', 'swashbuckler'},
#  {'Crime',
#   'Film-Noir',
#   'Mystery',
#   'afi 100 (thrills)',
#   'black and white',
#   "erlend's dvds",
#   'famous theme song',
#   'fox film noir series',
#   'national film registry',
#   'noir',
#   'oscar (best cinematography)',
#   'vincent price'},
#  {'Drama',
#   'Fantasy',
#   'Romance',
#   'almost favorite',
#   'ghosts',
#   'ghosts/afterlife',
#   'it was an absolutely lovely',
#   'off beat romance. truly charming.',
#   'single woman'},
#  {'Drama',
#   'adapted from:book',
#   'based on book',
#   'hw classics',
#   'not corv lib',
#   'shangri-la'},
#  {'Comedy',
#   'Musical',
#   'Romance',
#   'astaire and rogers',
#   'clv',
#   'national film registry'},
#  {'Comedy',
#   'Drama',
#   'War',
#   'afi 100 (laughs)',
#   'best performance:  carole lombard as maria tura',
#   'bfi classic',
#   'black comedy',
#   'classic',
#   'dark comedy',
#   'holocaust film',
#   'national film registry',
#   'remade',
#   'the shoah',
#   'world war ii'},
#  {'Comedy',
#   'afi 100 (laughs)',
#   'alan mowbray',
#   'alice brady',
#   'awesome',
#   'butler',
#   'carole lombard',
#   'classic',
#   'comedy',
#   'criterion',
#   'eugene pallette',
#   'friends should see',
#   'gail patrick',
#   'great depression',
#   'homeless',
#   'j netflix',
#   'national film registry',
#   'screwball',
#   'wealth',
#   'william powell'},
#  {'Drama',
#   'afi #82',
#   'afi 100',
#   'drama',
#   'earthy',
#   'elegiac',
#   'elizabeth taylor',
#   'epic',
#   'james dean',
#   'lavish',
#   'melancholy',
#   'national film registry',
#   'oil',
#   'oscar (best directing)',
#   'poignant',
#   'realistic',
#   'rock hudson',
#   'stirring',
#   'sweeping',
#   "tumey's dvds"},
#  {'Drama',
#   'adapted from:book',
#   'author:john steinbeck',
#   'based on a book',
#   'elia kazan',
#   'exceptional acting',
#   'friends should see',
#   'john steinbeck',
#   'netwatch',
#   'oscar (best supporting actress)',
#   'sure thing'},
#  {'Comedy',
#   'Mystery',
#   'afi 100 (laughs)',
#   'classic',
#   'comedy',
#   'national film registry',
#   'nick and nora charles',
#   'nick and nora charles (series)',
#   'post-prohibition',
#   'quirky'},
#  {'Comedy',
#   'Romance',
#   "adapted from b'way",
#   'afi 100 (laughs)',
#   'battle of the sexes',
#   'best performance:  rosalind russell as hildy johnson',
#   'biting',
#   'cary grant',
#   'classic',
#   'dialogue driven',
#   'great screenplays',
#   'humorous',
#   'madcap',
#   'members of the press',
#   'national film registry',
#   'newspaper theme',
#   'perfect',
#   'playlist',
#   'quirky',
#   'satirical',
#   'screwball',
#   'screwball comedy',
#   'talky',
#   'work ethics'},
#  {'70mm',
#   'Adventure',
#   'Comedy',
#   'clv',
#   'david niven',
#   'dvd-video',
#   'oscar (best cinematography)',
#   'oscar (best picture)',
#   'race'},
#  {'Drama',
#   'Fantasy',
#   'Romance',
#   'afi #11',
#   'afi 100',
#   'afi 100 (cheers)',
#   'alternate reality',
#   'alternate universe',
#   'angel',
#   'angelic intervention',
#   'awesome',
#   'best holocaust movie ever',
#   'best performance:  james stewart as george bailey',
#   'brothers',
#   'christmas',
#   'classic',
#   'corporations',
#   'drama',
#   'emerson must see',
#   "erlend's dvds",
#   'family',
#   'fantasy',
#   'favorite',
#   'favourite',
#   'first love',
#   'frank capra',
#   'google video',
#   'hearing impairment',
#   'heartwarming',
#   'hitchcock',
#   'holiday',
#   'hope',
#   'imdb top 250',
#   'inspirational',
#   'james stewart',
#   'jimmy stewart',
#   'library',
#   'library vhs',
#   'made me cry',
#   'money',
#   'national film registry',
#   'owned',
#   'romance',
#   'seen more than once',
#   'small town',
#   'story',
#   'tediously sacchrine',
#   'totalmente excelente',
#   "tumey's dvds",
#   'uplifting',
#   'usa',
#   'utopia',
#   'want',
#   'world war ii',
#   'x-mas movie',
#   'xmas',
#   'xmas theme'},
#  {'Drama',
#   'afi',
#   'afi #28',
#   'afi 100',
#   'afi 100 (cheers)',
#   'angry',
#   'black and white',
#   'boy scouts',
#   'classic',
#   'classic jimmy stewart',
#   'claude rains',
#   'democratic fantasy',
#   "didn't finish",
#   'disturbing',
#   'drama',
#   'edward arnold',
#   "erlend's dvds",
#   'fighting the system',
#   'frank capra',
#   'great cast excellent',
#   'great movie',
#   'guy kibbee',
#   'heartwarming',
#   'humorous',
#   'imdb top 250',
#   'inspiring',
#   'james stewart',
#   'jean arthur',
#   'jimmy stewart puts forth a great performance',
#   'national film registry',
#   'passionate',
#   'political',
#   'political corruption',
#   'politics',
#   'satirical',
#   'social injustice',
#   'topic:us political corruption',
#   "tumey's dvds",
#   'underdogs',
#   'us senate',
#   'usa film registry',
#   'want to see again',
#   'wonderfully warm and amusing'},
#  {'Comedy',
#   'afi #97',
#   'afi 100',
#   'afi 100 (laughs)',
#   'afi top 100 (#97)',
#   'afi top 100 laughs (#14)',
#   'afi top 100 passions (#51)',
#   'animal:dog',
#   'animal:leopard',
#   'baby',
#   'best performance:  cary grant as dr. david huxley',
#   'bibliothek',
#   "can't remember",
#   'cary grant',
#   'cary grant&katherine hepburn',
#   'classic',
#   'clv',
#   'comedy',
#   'dvd-r',
#   'easygoing',
#   'emerson must see',
#   'favorite',
#   'funny as hell',
#   'genre:romantic comedy',
#   'howard hawkes',
#   'howard hawks',
#   'humorous',
#   'imdb top 250',
#   'irreverent',
#   'katherine hepburn',
#   'leopard',
#   'madc',
#   'national film registry',
#   'opposites attract',
#   'otherwise engaged',
#   'paleontologist as protagonist',
#   'plot point:dinosaur skeleton',
#   'psychiatrist as character',
#   'quirky',
#   'related:bringing up baby (1938)',
#   'romance',
#   'romantic comedy',
#   'screwball',
#   'screwball comedy',
#   'setting:golf course (scene)',
#   'subgenre:screwball farce',
#   'subgenre:slapstick (mild)',
#   "tumey's dvds",
#   'urbane',
#   'witty',
#   'wonderfully warm and amusing'},
#  {'Drama', 'Romance', 'adoption', 'cary grant'},
#  {'Drama'},
#  {'Comedy', 'Mystery'},
#  {'?adapted from:book', 'Drama', 'subscription'},
#  {'Crime', 'Drama'},
#  {'Drama'},
#  {'Crime', 'Drama'},
#  {'Musical', 'danny kaye'},
#  {'Romance', 'Western', "tumey's dvds"},
#  {'Drama',
#   'Mystery',
#   'Thriller',
#   'adapted from:book',
#   'alfred hitchcock',
#   'breakthroughs',
#   'charming',
#   'classic',
#   'clv',
#   'criterion',
#   'dvd-video',
#   "erlend's dvds",
#   'fugitive',
#   'handcuffs',
#   'hitchcock',
#   'janus 50',
#   'literary adaptation',
#   'memory guy',
#   'not true to original version',
#   'secrets',
#   'spy',
#   'theatre',
#   'train',
#   "tumey's dvds",
#   'wrongly accused'},
#  {'War'},
#  {'Western'},
#  {'Horror',
#   'Sci-Fi',
#   'Thriller',
#   'afi 100 (thrills)',
#   'black and white',
#   'creepy',
#   'disturbing',
#   'george a. romero',
#   'gruesome',
#   'horror',
#   'man vs. beast',
#   'menacing',
#   'my movies',
#   'national film registry',
#   'ominous',
#   'paranoid',
#   'race issues',
#   'romero original',
#   'scared the hell outta me',
#   "sven's to see list",
#   'visceral',
#   'zombie',
#   'zombies'},
#  {'Adventure',
#   'Comedy',
#   'Romance',
#   'War',
#   'affectionate',
#   'afi #17',
#   'afi 100',
#   'afi 100 (cheers)',
#   'boat',
#   'bogart & hepburn',
#   'charming',
#   'classic',
#   'heartwarming',
#   'humorous',
#   'humphrey bogart',
#   'imdb top 250',
#   'jungle',
#   'katherine hepburn',
#   'literary adaptation',
#   'missionary',
#   'national film registry',
#   'oscar (best actor)',
#   'river',
#   'road picture',
#   'robert morley',
#   'rousing',
#   'talky',
#   'tense',
#   "tumey's dvds",
#   'vhs',
#   'water'},
#  {'Adventure', 'Comedy', 'Crime', 'Drama', 'Romance', 'crime', 'taped'},
#  {'?author:tennessee williams',
#   'Drama',
#   'based on a play',
#   'bibliothek',
#   'classic',
#   'tennesse williams',
#   'tennessee williams'},
#  {'Drama'},
#  {'Comedy', 'Drama', 'afi 100 (cheers)', 'journalism'},
#  {'Drama', 'Romance', 'own'},
#  {'Comedy', 'Musical'},
#  {'Romance',
#   'War',
#   'adapted from:book',
#   'author:hemingway',
#   'based on a book',
#   'ernest hemingway',
#   'hemingway',
#   'literary adaptation',
#   'oscar (best cinematography)'},
#  {'Mystery'},
#  {'Drama', 'War'},
#  {'Action'},
#  {'Drama'},
#  {'Drama', 'melodrama', 'not corv lib'},
#  {'Romance', 'gay', 'uk'},
#  {'Comedy', 'Drama'},
#  {'Documentary'},
#  {'Adventure', 'Children', 'animal movie', 'flashy'},
#  {'Drama', 'Romance'},
#  {'Comedy', 'Drama'},
#  {'Drama'},
#  {'Action',
#   'Adventure',
#   'Thriller',
#   "can't remember",
#   'jean-claude van damme'},
#  {'Drama', 'ireland', 'k movie'},
#  {'Thriller', 'clive owen'},
#  {'Drama', 'physics', 'science', 'true story'},
#  {'1950s',
#   'Comedy',
#   'Drama',
#   'brothers',
#   'chelsea pier',
#   'failing business',
#   'food',
#   'ian holm',
#   'immigrant',
#   'immigrants',
#   'isabella rossellini',
#   'italian',
#   'italian cooking',
#   'italian music',
#   'italians',
#   'keystone',
#   'kitchen',
#   'new jersey',
#   'restaurant',
#   'stanley tucci',
#   'timpano',
#   'tony shalub'},
#  {'1',
#   'Action',
#   'Crime',
#   'Drama',
#   'Thriller',
#   'action',
#   'bruce willis',
#   "can't remember",
#   'christopher walken',
#   'nudity (rear)',
#   'nudity (topless - brief)'},
#  {'Drama', 'Thriller'},
#  {'Action', 'Crime'},
#  {'Crime',
#   'Film-Noir',
#   'cherlize theron',
#   'james spader',
#   'nudity (topless - notable)',
#   'ub recommended'},
#  {'Crime'},
#  {'Comedy'},
#  {'Comedy'},
#  {'Drama', 'Thriller', 'ethical', 'gene hackman'},
#  {'Action', 'Thriller', 'steven seagal'},
#  {'Children',
#   'Comedy',
#   'david selby',
#   'emilio estevez',
#   'heidi kling',
#   'hockey',
#   'jeffrey nordling',
#   'joshua jackson',
#   'sport:ice hockey',
#   'sports'},
#  {'Drama',
#   'adapted from:book',
#   'author:john grisham',
#   "can't remember",
#   'courtroom drama',
#   'death penalty',
#   'gene hackman',
#   'john grisham',
#   'murder',
#   'racism'},
#  {'Children', 'Comedy', 'Western', 'disney', 'disney studios', 'don knotts'},
#  {'Adventure', 'Western', 'biography', 'history'},
#  {'Adventure',
#   'Children',
#   'Fantasy',
#   'aliens',
#   'betamax',
#   'disney',
#   'disney studios',
#   'telepathy'},
#  {'Children',
#   'Comedy',
#   'beetle',
#   'buddy hackett',
#   'cars',
#   'david tomlinson',
#   'dean jones',
#   'disney',
#   'disney studios',
#   'dvd',
#   'herbie the love bug (series)',
#   'joe flynn',
#   'kids special',
#   'michelle lee',
#   'race',
#   'volkswagen'},
#  {'Adventure',
#   'Children',
#   'Comedy',
#   'herbie the love bug (series)',
#   'probably saw this and loved it.'},
#  {'Children',
#   'Drama',
#   'animal:dog',
#   'animals die :(',
#   'beverly washburn',
#   "children's drama",
#   'chuck connors',
#   'classic',
#   'dog',
#   'dorothy mcguire',
#   'fess parker',
#   'jeff york',
#   'sad',
#   'tear jerker',
#   'way way too sad'},
#  {'Children',
#   'Comedy',
#   'Romance',
#   'brian keith',
#   "can't remember",
#   'hayley mills',
#   "maureen o'hara",
#   'movie to see',
#   'okay',
#   'summer camp',
#   'the original is soooo much better than the later version. tells you what it is like to feel good.',
#   'twins',
#   'twins separated at birth',
#   'twins/inter-related lives?'},
#  {'Children',
#   'Comedy',
#   'Drama',
#   'directorial debut',
#   'disney',
#   'disney studios',
#   'hayley mills',
#   'jane wyman',
#   'karl malden',
#   'nancy olson',
#   'richard egan',
#   'small town'},
#  {'Adventure', 'Children', 'Drama', 'nostalgic'},
#  {'Children', 'Comedy', 'animal:dog'},
#  {'Adventure',
#   'Children',
#   'based on a book',
#   'childhood flashback',
#   'childhood memories',
#   'deserted island',
#   'disney',
#   'disney studios',
#   'family',
#   'island',
#   'shipwreck',
#   'stranded',
#   'switching places'},
#  {'Children', 'Comedy', 'Mystery', 'disney', 'family'},
#  ...]

# %%
model = gensim.models.word2vec.Word2Vec(tag_genre_data, vector_size=100, window=100, sg=1, hs=0, epochs=50, min_count=5)

# %% [markdown]
# Word2Vec 함수는 Gensim 라이브러리에서 제공하는 기능으로, 단어를 벡터로 표현하는 Word2Vec 모델을 만듭니다.
# 여기에는 아래 인자값이 사용됩니다.
#
# - tag_genre_data : 이것은 단어를 학습하기 위한 문장들의 리스트입니다. 각 문장은 단어의 리스트로 표현되어야 합니다.
#
# - vector_size : 이것은 단어 벡터의 크기를 결정합니다. 즉, 각 단어가 몇 차원의 벡터로 표현될지를 지정합니다. 일반적으로 100차원 또는 300차원이 많이 사용됩니다.
#
# - window : 이것은 주변 단어의 개수를 지정합니다. 주어진 단어의 좌우로 몇 개의 단어를 볼 것인지를 의미합니다. 예를 들어, window=5는 좌우 5개의 단어를 참조합니다.
#
# - sg : 이것은 Word2Vec 모델을 학습할 때 사용되는 알고리즘을 선택합니다. sg=1은 Skip-gram 알고리즘을 사용하고, sg=0은 CBOW (Continuous Bag of Words) 알고리즘을 사용합니다. 일반적으로 Skip-gram 알고리즘이 더 성능이 좋다고 알려져 있습니다.
#
# - hs : 이것은 Hierarchical Softmax를 사용할지 여부를 결정합니다. hs=1은 사용하고, hs=0은 사용하지 않습니다. Hierarchical Softmax는 계산 효율을 높이기 위한 방법 중 하나입니다.
#
# - epochs : 이것은 전체 데이터셋을 몇 번 반복해서 학습할지를 결정합니다. 에포크(epoch)는 전체 데이터셋에 대해 한 번 학습을 완료한 상태를 의미합니다.
#
# - min_count : 이것은 모델이 학습에 사용할 단어의 최소 등장 빈도를 결정합니다. 이 값보다 빈도가 낮은 단어들은 무시됩니다. 일반적으로 너무 적게 등장한 단어는 모델의 성능에 도움이 되지 않으므로 이 값을 설정하여 제거하는 것이 좋습니다.
#
# 따라서 주어진 코드는 단어 벡터의 크기가 100이고 주변 단어를 100개까지 고려하는 Skip-gram 모델을 학습하며, 50번의 에포크 동안 데이터셋을 사용하여 학습합니다. 단어의 등장 빈도가 5보다 작은 단어는 무시됩니다. Hierarchical Softmax는 사용하지 않습니다.

# %%
# anime 태그와 비슷한 태그를 확인한다
model.wv.most_similar('anime')
# Out:
# [('zibri studio', 0.7914258241653442),
#  ('studio ghibli', 0.7864949107170105),
#  ('miyazaki', 0.7724219560623169),
#  ('pelicula anime', 0.7545306086540222),
#  ('hayao miyazaki', 0.7425793409347534),
#  ('japan', 0.6656797528266907),
#  ('Animation', 0.5605572462081909),
#  ('curse', 0.4687414765357971),
#  ('wilderness', 0.46351557970046997),
#  ('samurai', 0.4605865776538849)]

# %%
# Word2vecContent 추천
from src.word2vec import Word2vecRecommender
recommender = Word2vecRecommender()
recommend_result = recommender.recommend(movielens)

# %%
# 평가
metric_calculator = MetricCalculator()
metrics = metric_calculator.calc(
    movielens.test.rating.tolist(), recommend_result.rating.tolist(),
    movielens.test_user2items, recommend_result.user2items, k=10)
print(metrics)
# Out:
# rmse=0.000, Precision@K=0.010, Recall@K=0.034
